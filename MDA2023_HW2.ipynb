# %% [markdown]
# # Data Mining Course Spark Exercise
# ## Sharif University of Technology
#
# In this notebook we are going to analyze farsi news.
# Outline of the exercise:
# * Dataset preparation
# * Preprocessing
# * Exploration
# * Word Collections
#
# ## Warning: RDD api only
# You **can not** use Dataframe, Dataset, mllib, ml, ... apis of spark in this exercise. You should only use the [RDD api](http://spark.apache.org/docs/2.1.0/api/python/pyspark.html#pyspark.RDD).

# %% [markdown]
# # Please enter your name below:
# # Name: Mohammad Mehdi Zare
# # Student Number:

# %% [markdown]
# # Section 1: Dataset prepartition
# This section you need to download [dataset](https://drive.google.com/file/d/1bRxHQDzPr6wDimbM7b89H47kH8O3YV8Y/view?usp=sharing) in a directory you work. After that run the below cell to untar the datase.
#
# **Note 1: Don't change the below command.**
#
# **Note 2: If you use Windows OS, unzip the dataset manually.**

# %% [markdown]
# ## Install Pypark & Initialization
# Uncomment this section if you use google colab or local pc

# %%
# !pip install python_bidi
# !pip install hazm
# !pip install pyspark
# Out:
# Requirement already satisfied: python_bidi in c:\users\mehdi\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: six in c:\users\mehdi\anaconda3\lib\site-packages (from python_bidi) (1.16.0)
# Requirement already satisfied: hazm in c:\users\mehdi\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: nltk==3.3 in c:\users\mehdi\anaconda3\lib\site-packages (from hazm) (3.3)
# Requirement already satisfied: six in c:\users\mehdi\anaconda3\lib\site-packages (from nltk==3.3->hazm) (1.16.0)
# Requirement already satisfied: pyspark in c:\users\mehdi\anaconda3\lib\site-packages (3.5.0)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\mehdi\anaconda3\lib\site-packages (from pyspark) (0.10.9.7)

# %%
# !pip install findspark
# Out:
# Requirement already satisfied: findspark in c:\users\mehdi\anaconda3\lib\site-packages (2.0.1)

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .appName("HW2") \
    .master("local[*]") \
    .getOrCreate()

sc=spark.sparkContext

# %%
# unzip data
# !tar -xzvf "/content/drive/MyDrive/big data/data.tar.gz" -C "/content/drive/MyDrive/big data/"

# %% [markdown]
# # Reading the data

# %%
news_rdd = sc.textFile("news_data2.json")

# news_rdd=sc.parallelize(news_rdd.takeSample(False, 200000, 12))

# %% [markdown]
# # Section 2: Preprocessing
# This section we try to normalize news and remove useless characters (for example /n and /u200c and ...). Also find and remove stop words.

# %%
# import neccesary packages here
import json
import string
from math import log10
from hazm.utils import stopwords_list
import numpy as np
import matplotlib.pyplot as plt

# %%
news_rdd1= news_rdd
json_rdd = news_rdd1.map(lambda x : json.loads(x))

# %%
json_rdd.take(1)
# Out:
# [{'body': 'سرمربی ملوان درباره تصاویر وایرالی دیدار با نساجی یک پست جالب منتشر کرد.\n\nبه گزارش "ورزش سه"، مهدی تارتار با خوشحالی عجیب و غریب دقیقه ۹۰+۳ یکی از چهرههای جالب این هفته لیگ برتر را به خود اختصاص داد که موردتوجه هواداران فوتبال قرار گرفت.\n\nتارتار حالا با انتشار یک پست اینستاگرامی از تصاویر جشن و خوشحالی خود نوشته که این جادوی طرفداران انزلی است که او را از خود بی خود کرده است.\n\nسرمربی ملوان همچنین وعده داده که تیمش در ادامه فصل نیز با تمام توان خواهد جنگید تا رضایت هواداران را به خود جلب کند.\n\nنوشته او را در ادامه میخوانید:\n\nحالا که به عکسها نگاه میکنم، متحیر میشوم. یادم نمیآید هرگز اینطور شوری گرفته باشم. این جادوی شماست، شما که روی سکو آنچنان حس و انرژی به ما میدهید که لحظه پیروزی برایمان وصفناشدنی باشد. از روی سکوها تا لب خط، از پای تلویزیونها تا در مستطیل سبز؛ ما همدل و یکصدا پیش میرویم. باهم میجنگیم و باهم میخندیم و هرروز تلاش میکنیم تا این خنده را روی صورت شما نگه داریم. این پیروزی برای شماست، شما مردان نیک روی چمن و شما مردمان نیک روی سکو \U0001fa75🤍',
#   'image_title_url': 'https://news-cdn.varzesh3.com/pictures/2023/08/09/A/a5l2b23f.jpg',
#   'language': 'fa',
#   'source': 'ورزش سه',
#   'title': 'نوشته خاص تارتار برای لحظه جنجالی (عکس)',
#   'date_published': 1696909606,
#   'uid': '68feae4bbbedc2d54adbb2369',
#   'url': 'https://www.varzesh3.com/news/1971626/%D9%86%D9%88%D8%B4%D8%AA%D9%87-%D8%AE%D8%A7%D8%B5-%D8%AA%D8%A7%D8%B1%D8%AA%D8%A7%D8%B1-%D8%A8%D8%B1%D8%A7%DB%8C-%D9%84%D8%AD%D8%B8%D9%87-%D8%AC%D9%86%D8%AC%D8%A7%D9%84%DB%8C-%D8%B9%DA%A9%D8%B3',
#   'crawler_timestamp': 1696910655,
#   'ingestor_timestamp': 1696925866,
#   'summary': 'سرمربی ملوان درباره تصاویر وایرالی دیدار با نساجی یک پست جالب منتشر کرد.',
#   'hostname': 'varzesh3.com',
#   'parser_categories': [],
#   'keywords': ['سرمربی ملوان', 'لیگ برتر', 'مستطیل سبز', 'انزلی'],
#   'parser_keyword': ['ملوان',
#    'نساجی مازندران',
#    'مهدی تارتار',
#    'لیگ برتر ایران',
#    'فوتبال'],
#   'author': '',
#   'processed_body': 'به گزارش “ورزش سه”، مهدی تارتار با خوشحالی عجیب و غریب دقیقه ۹۰+۳ یکی از چهره\u200cهای جالب این هفته لیگ برتر را به خود اختصاص داد که موردتوجه هواداران فوتبال قرار گرفت.\n\nتارتار حالا با انتشار یک پست اینستاگرامی از تصاویر جشن و خوشحالی خود نوشته که این جادوی طرفداران انزلی است که او را از خود بی خود کرده است.\n\nسرمربی ملوان همچنین وعده داده که تیمش در ادامه فصل نیز با تمام توان خواهد جنگید تا رضایت هواداران را به خود جلب کند.\n\nنوشته او را در ادامه می\u200cخوانید:\n\nحالا که به عکس\u200cها نگاه می\u200cکنم، متحیر می\u200cشوم. یادم نمی\u200cآید هرگز اینطور شوری گرفته باشم. این جادوی شماست، شما که روی سکو آنچنان حس و انرژی به ما می\u200cدهید که لحظه پیروزی برایمان وصف\u200cناشدنی باشد. از روی سکوها تا لب خط، از پای تلویزیون\u200cها تا در مستطیل سبز؛ ما همدل و یکصدا پیش می\u200cرویم. باهم می\u200cجنگیم و باهم می\u200cخندیم و هرروز تلاش می\u200cکنیم تا این خنده را روی صورت شما نگه داریم. این پیروزی برای شماست، شما مردان نیک روی چمن و شما مردمان نیک روی سکو \U0001fa75🤍',
#   'categories': ['sports'],
#   'ner_tags': [{'type': 'PER', 'entity': 'تارتار'},
#    {'type': 'POST', 'entity': 'سرمربی ملوان'},
#    {'type': 'ORG', 'entity': 'وایرالی'},
#    {'type': 'ORG', 'entity': 'ورزش سه'},
#    {'type': 'PER', 'entity': 'مهدی تارتار'},
#    {'type': 'EVE', 'entity': 'لیگ برتر'},
#    {'type': 'PER', 'entity': 'تارتار'},
#    {'type': 'GPE', 'entity': 'انزلی'},
#    {'type': 'POST', 'entity': 'سرمربی ملوان'}]}]

# %%
rows=json_rdd.count()
print("number of news : "+ str(rows))
# Out:
# number of news : 5000

# %%
# I think some news are duplicated, so, I decided to test and remove extra news. 
json_rdd = json_rdd.map(lambda x : (x['uid'],x))\
.reduceByKey(lambda x,y : x)\
.map(lambda x: x[1])

# %%
extra=rows-json_rdd.count()
print("number of extra news : "+ str(extra))
# Out:
# number of extra news : 0

# %%
def remove_punc(x):
    punks = '!"#$%&()*+,-./:;<=>?@[\]^_`{|}~1234567890۱۲۳۴۵۶۷۸۹۰،؛'
    no_punc = x
    for ch in punks:
      no_punc = no_punc.replace(ch , " ")
    return no_punc.replace("\n" , "").replace("\u200c" , " ")

def remove_stopwords(rdd):
  stopwords = stopwords_list()
  rdd=rdd.replace("های", "").replace("میشود", "")
  rdd = rdd.split()
  result = [word for word in rdd if not word in stopwords]
  return ' '.join(result)

def clean_rdd_util(T , function):
  T['body'] = function(T['body'])
  T['title'] = T['title'].replace("\u200c", " ")
  if "keywords" in T:
    T['keywords']= [function(x) for x in T['keywords']]
  else:
      T['keywords']=[]
  return T


def cleaning(rdd):
  rdd = rdd.map(lambda x: clean_rdd_util(x , remove_punc))
  rdd = rdd.map(lambda x: clean_rdd_util(x, remove_stopwords))
  return rdd;

# %%
cleaned= cleaning(json_rdd)

# %%
cleaned.take(15)
# Out:
# [{'body': 'سرمربی ملوان تصاویر وایرالی دیدار نساجی پست جالب منتشر گزارش ورزش مهدی تارتار خوشحالی عجیب غریب دقیقه چهره جالب هفته لیگ برتر اختصاص موردتوجه هواداران فوتبال قرار تارتار انتشار پست اینستاگرامی تصاویر جشن خوشحالی نوشته جادوی طرفداران انزلی سرمربی ملوان وعده تیمش ادامه فصل توان خواهد جنگید رضایت هواداران جلب نوشته ادامه میخوانید عکسها نگاه میکنم متحیر میشوم یادم نمیآید هرگز اینطور شوری باشم جادوی شماست سکو آنچنان حس انرژی میدهید لحظه پیروزی برایمان وصفناشدنی سکوها لب خط پای تلویزیونها مستطیل سبز همدل یکصدا میرویم باهم میجنگیم باهم میخندیم هرروز تلاش میکنیم خنده صورت نگه پیروزی شماست مردان نیک چمن مردمان نیک سکو \U0001fa75🤍',
#   'image_title_url': 'https://news-cdn.varzesh3.com/pictures/2023/08/09/A/a5l2b23f.jpg',
#   'language': 'fa',
#   'source': 'ورزش سه',
#   'title': 'نوشته خاص تارتار برای لحظه جنجالی (عکس)',
#   'date_published': 1696909606,
#   'uid': '68feae4bbbedc2d54adbb2369',
#   'url': 'https://www.varzesh3.com/news/1971626/%D9%86%D9%88%D8%B4%D8%AA%D9%87-%D8%AE%D8%A7%D8%B5-%D8%AA%D8%A7%D8%B1%D8%AA%D8%A7%D8%B1-%D8%A8%D8%B1%D8%A7%DB%8C-%D9%84%D8%AD%D8%B8%D9%87-%D8%AC%D9%86%D8%AC%D8%A7%D9%84%DB%8C-%D8%B9%DA%A9%D8%B3',
#   'crawler_timestamp': 1696910655,
#   'ingestor_timestamp': 1696925866,
#   'summary': 'سرمربی ملوان درباره تصاویر وایرالی دیدار با نساجی یک پست جالب منتشر کرد.',
#   'hostname': 'varzesh3.com',
#   'parser_categories': [],
#   'keywords': ['سرمربی ملوان', 'لیگ برتر', 'مستطیل سبز', 'انزلی'],
#   'parser_keyword': ['ملوان',
#    'نساجی مازندران',
#    'مهدی تارتار',
#    'لیگ برتر ایران',
#    'فوتبال'],
#   'author': '',
#   'processed_body': 'به گزارش “ورزش سه”، مهدی تارتار با خوشحالی عجیب و غریب دقیقه ۹۰+۳ یکی از چهره\u200cهای جالب این هفته لیگ برتر را به خود اختصاص داد که موردتوجه هواداران فوتبال قرار گرفت.\n\nتارتار حالا با انتشار یک پست اینستاگرامی از تصاویر جشن و خوشحالی خود نوشته که این جادوی طرفداران انزلی است که او را از خود بی خود کرده است.\n\nسرمربی ملوان همچنین وعده داده که تیمش در ادامه فصل نیز با تمام توان خواهد جنگید تا رضایت هواداران را به خود جلب کند.\n\nنوشته او را در ادامه می\u200cخوانید:\n\nحالا که به عکس\u200cها نگاه می\u200cکنم، متحیر می\u200cشوم. یادم نمی\u200cآید هرگز اینطور شوری گرفته باشم. این جادوی شماست، شما که روی سکو آنچنان حس و انرژی به ما می\u200cدهید که لحظه پیروزی برایمان وصف\u200cناشدنی باشد. از روی سکوها تا لب خط، از پای تلویزیون\u200cها تا در مستطیل سبز؛ ما همدل و یکصدا پیش می\u200cرویم. باهم می\u200cجنگیم و باهم می\u200cخندیم و هرروز تلاش می\u200cکنیم تا این خنده را روی صورت شما نگه داریم. این پیروزی برای شماست، شما مردان نیک روی چمن و شما مردمان نیک روی سکو \U0001fa75🤍',
#   'categories': ['sports'],
#   'ner_tags': [{'type': 'PER', 'entity': 'تارتار'},
#    {'type': 'POST', 'entity': 'سرمربی ملوان'},
#    {'type': 'ORG', 'entity': 'وایرالی'},
#    {'type': 'ORG', 'entity': 'ورزش سه'},
#    {'type': 'PER', 'entity': 'مهدی تارتار'},
#    {'type': 'EVE', 'entity': 'لیگ برتر'},
#    {'type': 'PER', 'entity': 'تارتار'},
#    {'type': 'GPE', 'entity': 'انزلی'},
#    {'type': 'POST', 'entity': 'سرمربی ملوان'}]},
#  {'body': 'ایسنا قم کاراتهکا قمی درخشش پیکار کشوری رده سنی پایه مرحله انتخابی تیم ملی تاتامی میروند گزارش ایسنا مرحله انتخابی تیم ملی کاراته رده پایه مهرماه تهران برگزار کاراته کا قمی مرحله انتخابی تیم ملی استان لرستان موفق کسب مدال مرحله انتخابی تیم ملی حضور خواهند شایان ذکر مسابقات انتخابی مرحله سیدمحمدپارسامیرمهدی مدال برنز کیلوگرم نوجوانان سیدمحمدصدرافروغی برنز کیلوگرم نوجوانان فرید معصومی برنز کیلوگرم رده سال کسب همراه نفرات رنکینگ کاراته وان ایران مرحله انتخابی تیم ملی کاراته حضور مییابند',
#   'image_title_url': 'https://cdn.isna.ir/d/2023/10/07/4/62755904.jpg?ts=1696683917882',
#   'language': 'fa',
#   'source': 'ایسنا',
#   'title': 'مرحله دوم انتخابی تیم های ملی کاراته با حضور ورزشکاران قمی',
#   'date_published': 1696909680,
#   'uid': '2ad5a78866237762a3f742c51',
#   'url': 'https://www.isna.ir/news/1402071812124/مرحله-دوم-انتخابی-تیم-های-ملی-کاراته-با-حضور-ورزشکاران-قمی',
#   'crawler_timestamp': 1696909929,
#   'ingestor_timestamp': 1696925868,
#   'summary': 'کاراته\u200cکاهای قمی بعد از درخشش در پیکارهای کشوری رده\u200cهای سنی پایه، در مرحله دوم انتخابی تیم ملی روی تاتامی می\u200cروند.',
#   'hostname': 'isna.ir',
#   'parser_categories': ['استان ها > قم'],
#   'keywords': ['انتخابی تیم ملی کاراته',
#    'انتخابی تیم ملی',
#    'مسابقات انتخابی مرحله',
#    'فرید معصومی'],
#   'parser_keyword': ['انتخابی تیم ملی کاراته'],
#   'author': 'محسن امینی',
#   'processed_body': 'به گزارش ایسنا مرحله دوم انتخابی تیم های ملی کاراته در رده های پایه ۱۹ تا ۲۲ مهرماه در تهران برگزار می شود و کاراته کاهای قمی که در مرحله اول انتخابی تیم ملی در استان لرستان موفق به کسب مدال شدند در مرحله دوم انتخابی تیم ملی نیز حضور خواهند داشت.\nشایان ذکر است در مسابقات انتخابی مرحله اول سیدمحمدپارسامیرمهدی مدال برنز ۷۰ کیلوگرم نوجوانان، سیدمحمدصدرافروغی برنز ۵۵ کیلوگرم نوجوانان و فرید معصومی برنز ۷۵ کیلوگرم رده زیر ۲۱ سال را کسب کردند و به همراه نفرات ۱ و ۲ رنکینگ کاراته وان ایران در مرحله دوم انتخابی تیم های ملی کاراته حضور می\u200cیابند.\nانتهای پیام',
#   'categories': ['sports'],
#   'ner_tags': [{'type': 'ORG', 'entity': 'تیم\u200cهای ملی کاراته'},
#    {'type': 'POST', 'entity': 'ورزشکاران قمی'},
#    {'type': 'NORP', 'entity': 'کاراته\u200cکاهای قمی'},
#    {'type': 'ORG', 'entity': 'ایسنا'},
#    {'type': 'GPE', 'entity': 'تهران'},
#    {'type': 'ORG', 'entity': 'کاراته کاهای قمی'},
#    {'type': 'ORG', 'entity': 'تیم ملی'},
#    {'type': 'GPE', 'entity': 'لرستان'},
#    {'type': 'ORG', 'entity': 'تیم ملی'},
#    {'type': 'EVE', 'entity': 'مسابقات انتخابی مرحله'},
#    {'type': 'PER', 'entity': 'سیدمحمدپارسامیرمهدی'},
#    {'type': 'PER', 'entity': 'سیدمحمدصدرافروغی'},
#    {'type': 'PER', 'entity': 'فرید معصومی'},
ش به عملیات طوفان الاقصی در فلسطین با صدور بیانیه\u200cای اعلام کرد، عربستان تحولات و شرایط بی\u200cسابقه فلسطین و درگیری گروه\u200cهای فلسطینی با نیرو\u200cهای اشغالگر اسرائیلی را دنبال می\u200cکند. ریاض بار\u200cها درباره خطر انفجار اوضاع داخلی فلسطین در پی ادامه اشغالگری اسرائیل و محرومیت ملت فلسطین از حقوق قانونی خود و تکرار اقدامات تحریک\u200cآمیز سیستماتیک علیه مقدسات مسلمانان هشدار داده است.',
#   'categories': ['economy'],
#   'ner_tags': [{'type': 'PER', 'entity': 'محمد بن سلمان'},
#    {'type': 'EVE', 'entity': 'جنگ حماس'},
#    {'type': 'ORG', 'entity': 'اسرائیل'},
#    {'type': 'PER', 'entity': 'محمد بن سلمان'},
#    {'type': 'POST', 'entity': 'رئیس تشکیلات خودگردان فلسطین'},
#    {'type': 'GPE', 'entity': 'عربستان'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'PER', 'entity': 'محمد بنسلمان'},
#    {'type': 'POST', 'entity': 'رئیس تشکیلات خودگردان فلسطین'},
#    {'type': 'GPE', 'entity': 'عربستان'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'PER', 'entity': 'محمد بن سلمان'},
#    {'type': 'POST', 'entity': 'ولیعهد عربستان سعودی'},
#    {'type': 'PER', 'entity': 'محمود عباس'},
#    {'type': 'POST', 'entity': 'رئیس تشکیلات خودگردان فلسطین'},
#    {'type': 'GPE', 'entity': 'عربستان'},
#    {'type': 'GPE', 'entity': 'غزه'},
#    {'type': 'ORG', 'entity': 'خبرگزاری رسمی عربستان ( واس )'},
#    {'type': 'PER', 'entity': 'محمد بن سلمان'},
#    {'type': 'PER', 'entity': 'محمود عباس'},
#    {'type': 'GPE', 'entity': 'عربستان'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'POST', 'entity': 'ولیعهد سعودی'},
#    {'type': 'GPE', 'entity': 'عربستان'},
#    {'type': 'PER', 'entity': 'بن سلمان'},
#    {'type': 'PER', 'entity': 'عبدالفتاح السیسی'},
#    {'type': 'POST', 'entity': 'رئیس جمهوری مصر'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'NORP', 'entity': 'فلسطینیان'},
#    {'type': 'NORP', 'entity': 'صهیونیست\u200cها'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'POST', 'entity': 'سخنگوی ریاست\u200cجمهوری مصر'},
#    {'type': 'PER', 'entity': 'بن سلمان'},
#    {'type': 'PER', 'entity': 'السیسی'},
#    {'type': 'GPE', 'entity': 'مصر'},
#    {'type': 'GPE', 'entity': 'عربستان'},
#    {'type': 'NORP', 'entity': 'عربی'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'PER', 'entity': 'بن سلمان'},
#    {'type': 'PER', 'entity': 'عبدالله دوم'},
#    {'type': 'POST', 'entity': 'پادشاه اردن'},
#    {'type': 'NORP', 'entity': 'عربی'},
#    {'type': 'ORG', 'entity': 'خبرگزاری اردن'},
#    {'type': 'PER', 'entity': 'عبدالله دوم'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'NORP', 'entity': 'فلسطینی\u200cها'},
#    {'type': 'ORG', 'entity': 'وزارت امور خارجه عربستان سعودی'},
#    {'type': 'EVE', 'entity': 'طوفان الاقصی'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'GPE', 'entity': 'عربستان'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'NORP', 'entity': 'فلسطینی'},
#    {'type': 'NORP', 'entity': 'اسرائیلی'},
#    {'type': 'GPE', 'entity': 'ریاض'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'ORG', 'entity': 'اسرائیل'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'NORP', 'entity': 'مسلمانان'}]},
#  {'body': 'گزارش خبرگزاری فارس زنجان حسین محمدی معاون هماهنگی امور اقتصادی توسعه منابع استاندار زنجان امروز مدیران شرکت گاز اظهار توجه شناسایی واحد صنعتی پرمصرف توسط شرکت گاز استان واحدها سریعتر تامین سوخت جایگزین برنامه معاون هماهنگی امور اقتصادی توسعه منابع استاندار زنجان اشاره پیک مصرف سوخت گاز طبیعی استان زنجان ماه دی بهمن واحد صنعتی مدیریت صحیح ذخیرهسازی موقع سوخت جایگزین روز اوج مصرف نگران تعطیلی واحد تولیدی نباشند تاکید تامین سوخت پایدار مشترکان گاز طبیعی مصرف خانگی اصلیترین مصرف گاز طبیعی مشترکان خانگی رعایت صحیح مصرف میتوانند تامین گاز پایدار زمستان موثر محمدی استفاده سوخت جایگزین مدارس ارزیابی توجه سال گذشته خاطر افت سطح فشار گاز کشور روز مدارس استان تعطیلی امسال فرا فصول سرد افزایش مصرف گاز تامین تجهیز مدارس سوخت جایگزین برنامه معاون هماهنگی امور اقتصادی توسعه منابع استاندار زنجان ادامه تشویق اعمال تخفیف مشترکان مصرف تاکید قرار یاد آور توجه اعمال تخفیف تشویق مصرف برق جامعه بازخورد اجرای برنامه کاهش مصرف گاز تواند موثر سال گذشته گاز زنجان عملکرد مدیریت شبکه پایدار گاز شرکت گاز استان همجوار مدیریت پایداری شبکه گاز نارضایتی مختلف مصرف گاز استان نداشتم معاون هماهنگی امور اقتصادی توسعه منابع استاندار زنجان اذعان امیدواریم امسال مدیریت صحیح شرکت گاز همکاری مردم مسئولان مشکلی تامین سوخت واحد تولیدی تجاری ادارات دولتی مصارف خانگی نداشته باشیم پایان پیام',
#   'image_title_url': 'https://media.farsnews.ir/Uploaded/Files/Images/1402/02/22/14020222000295_Test_PhotoN.JPG',
#   'language': 'fa',
#   'source': 'خبرگزاری فارس',
#   'title': 'خبرگزاری فارس - واحدهای صنعتی پر مصرف به فکر سوخت جایگزین باشند',
#   'date_published': 1696909694,
#   'uid': 'f136d860f0dcbd6c98318e580',
#   'url': 'https://www.farsnews.ir/news/14020718000303/واحدهای-صنعتی-پر-مصرف-به-فکر-سوخت-جایگزین-باشند',
#   'crawler_timestamp': 1696910037,
#   'ingestor_timestamp': 1696925868,
#   'summary': 'معاون هماهنگی امور اقتصادی و توسعه منابع استاندار زنجان گفت: واحدهای تولیدی و صنعتی پر مصرف، از هم اکنون به فکر ذخیره\u200cسازی سوخت و استفاده از سوخت جایگزین باشند.',
#   'hostname': 'farsnews.ir',
#   'parser_categories': ['استانها - زنجان'],
#   'keywords': ['معاون هماهنگی امور اقتصادی توسعه منابع استاندار زنجان',
#    'معاون هماهنگی امور اقتصادی توسعه منابع',
#    'مدیران شرکت گاز',
#    'حسین محمدی'],
#   'parser_keyword': ['زنجان',
#    'گاز',
#    'شرکت گاز',
#    'استان زنجان',
#    'معاون اقتصادی',
#    'مصرف گاز',
#    'سوخت جایگزین',
#    'صنایع پر مصرف'],
#   'author': 'خبرگزاری فارس',
#   'processed_body': 'به گزارش خبرگزاری فارس از زنجان، حسین محمدی،\xa0معاون هماهنگی امور اقتصادی و توسعه منابع استاندار زنجان امروز در جمع مدیران شرکت گاز اظهار کرد: با توجه به شناسایی واحدهای صنعتی پرمصرف توسط شرکت گاز استان، این واحدها باید هر چه سریعتر نسبت به تامین سوخت جایگزین خود برنامه ریزی کنند.\nمعاون هماهنگی امور اقتصادی و توسعه منابع استاندار زنجان با اشاره به اینکه پیک مصرف سوخت گاز طبیعی در استان زنجان در ماه\u200cهای دی و بهمن است، افزود: واحدهای صنعتی با مدیریت صحیح و ذخیره\u200cسازی به موقع سوخت جایگزین برای روزهای اوج مصرف، نگران تعطیلی واحدهای تولیدی خود نباشند.\nوی با تاکید بر تامین سوخت پایدار برای مشترکان گاز طبیعی به ویژه مصرف کنندگان خانگی افزود: اصلی\u200cترین مصرف کنندگان گاز طبیعی مشترکان خانگی هستند که با رعایت صحیح مصرف می\u200cتوانند در تامین گاز پایدار در زمستان موثر باشند.\nمحمدی استفاده از سوخت جایگزین برای مدارس را نیز مهم ارزیابی کرد و افزود: با توجه به اینکه در سال گذشته به خاطر افت سطح فشار گاز در کشور، چند روز مدارس استان با تعطیلی مواجه شدند، امسال باید قبل از فرا رسیدن فصول سرد و افزایش مصرف گاز نسبت به تامین و تجهیز مدارس به سوخت جایگزین برنامه ریزی شود.\nمعاون هماهنگی امور اقتصادی و توسعه منابع استاندار زنجان در ادامه، تشویق و اعمال تخفیف برای مشترکان کم مصرف را مورد تاکید قرار داد و یاد آور شد: با توجه به اینکه اعمال تخفیف و تشویق در مصرف برق در جامعه بازخورد خوبی داشته است، اجرای این برنامه در کاهش مصرف گاز می تواند موثر باشد.\nوی با بیان اینکه سال گذشته گاز زنجان عملکرد خوبی در مدیریت شبکه پایدار گاز نسبت به شرکت\u200cهای گاز استان\u200cهای همجوار داشته است؛ افزود: با مدیریت و پایداری شبکه گاز، هیچ گونه نارضایتی در بخش\u200cهای مختلف مصرف گاز استان نداشته\u200cایم.\nمعاون هماهنگی امور اقتصادی و توسعه منابع استاندار زنجان اذعان\xa0داشت: امیدواریم امسال نیز با مدیریت صحیح شرکت گاز و همکاری مردم و مسئولان؛ مشکلی در تامین سوخت واحدهای تولیدی، تجاری، ادارات دولتی و مصارف خانگی نداشته باشیم.\nپایان پیام/',
#   'categories': ['social'],
#   'ner_tags': [{'type': 'POST',
#     'entity': 'معاون هماهنگی امور اقتصادی و توسعه منابع استاندار زنجان'},
#    {'type': 'ORG', 'entity': 'خبرگزاری فارس'},
#    {'type': 'GPE', 'entity': 'زنجان'},
#    {'type': 'PER', 'entity': 'حسین محمدی'},
#    {'type': 'POST',
#     'entity': 'معاون هماهنگی امور اقتصادی و توسعه منابع استاندار زنجان'},
#    {'type': 'POST', 'entity': 'مدیران شرکت گاز'},
#    {'type': 'ORG', 'entity': 'شرکت گاز'},
#    {'type': 'POST',
#     'entity': 'معاون هماهنگی امور اقتصادی و توسعه منابع استاندار زنجان'},
#    {'type': 'GPE', 'entity': 'زنجان'},
#    {'type': 'PER', 'entity': 'محمدی'},
#    {'type': 'POST',
#     'entity': 'معاون هماهنگی امور اقتصادی و توسعه منابع استاندار زنجان'},
#    {'type': 'GPE', 'entity': 'زنجان'},
#    {'type': 'ORG', 'entity': 'شبکه پایدار گاز'},
#    {'type': 'ORG', 'entity': 'شرکت\u200cهای گاز'},
#    {'type': 'POST',
#     'entity': 'معاون هماهنگی امور اقتصادی و توسعه منابع استاندار زنجان'},
#    {'type': 'ORG', 'entity': 'شرکت گاز'},
#    {'type': 'POST', 'entity': 'مسئولان'}]},
#  {'body': 'رئیس اداره اوقاف امور خیریه شهرستان نور ثبت وقف توسط حاج محمد چراغی شهرستان نور ارزش میلیارد ریال خانه بهداشت استقرار مرکز اورژانس همزمان هفته وقف خبر بهزاد صادقی گفتوگو خبرنگار فارس شهرستان نور اظهار همزمان هفته وقف واقف خیراندیش حاج محمد چراغی سند وقف تنظیم ثبت رسانید وقف ششدانگ اعیانی احداثی بهمساحت مربع روستای افراسیابکلا نیت ارائه خدمات بهداشتی بهنام شهید مدافع حرم علی جمشیدی وقف عام ارزش اعیانی احداثی میلیون تومان برآورد صادقی وقف ششدانگ اعیانی احداثی بهمساحت مربع ارزش میلیون تومان واقع گلندرود رویان جهت استفاده استقرار مرکز اورژانس فوریت پزشکی بهنام شهید مرتضی دیلمقانی گفتنی واقف خیراندیش محمد چراغی مجتمع عروس دریا طبقه ساختمان مسکونی نیت نگهداری تامین هزینه کودکان بیسرپرست بدسرپرست وقف گزارش فارس واقف خیراندیش محمد چراغی بزرگترین واقفان خیران کشور میرود ساخت کتابخانه مدرسه خانه محروم اقدامات ماندگاری رئیس سازمان اوقاف امور خیریه تجلیل قرار پایان پیام م',
#   'image_title_url': 'https://media.farsnews.ir/Uploaded/Files/Images/1402/07/18/14020718000150_Test_PhotoN.jpg',
#   'language': 'fa',
#   'source': 'خبرگزاری فارس',
#   'title': 'خبرگزاری فارس - احداث خانه بهداشت و مرکز اورژانس توسط یک خیر در شهرستان نور در قالب وقف',
#   'date_published': 1696909703,
#   'uid': '7b85bc41da526e89274f20958',
#   'url': 'https://www.farsnews.ir/news/14020718000234/احداث-خانه-بهداشت-و-مرکز-اورژانس-توسط-یک-خیر-در-شهرستان-نور-در-قالب',
#   'crawler_timestamp': 1696909926,
#   'ingestor_timestamp': 1696925869,
#   'summary': 'رئیس اداره اوقاف و امور خیریه شهرستان نور از ثبت وقف جدید توسط حاج محمد چراغی در شهرستان نور به ارزش ۷ میلیارد ریال برای خانه بهداشت و استقرار مرکز اورژانس همزمان با هفته وقف خبر داد.',
#   'hostname': 'farsnews.ir',
#   'parser_categories': ['استانها - مازندران'],
#   'keywords': ['رئیس اداره اوقاف امور خیریه شهرستان نور',
#    'رئیس سازمان اوقاف امور خیریه',
#    'مرکز اورژانس فوریت پزشکی',
#    'بهزاد صادقی'],
#   'parser_keyword': ['بهزاد صادقی',
#    'رئیس اداره اوقاف و امور خیریه شهرستان نور',
#    'وقف',
#    'حوزه درمان',
#    'خیر حاج محمد چراغی',
#    'استان مازندران',
#    'ترویج فرهنگ وقف'],
#   'author': 'خبرگزاری فارس',
#   'processed_body': 'بهزاد صادقی در گفت\u200c\u200cوگو با خبرنگار فارس در شهرستان نور اظهار کرد: همزمان با هفته وقف؛ واقف خیراندیش حاج محمد چراغی دو سند وقف جدید تنظیم و به ثبت رسانید.\nوی گفت: وقف ششدانگ اعیانی احداثی به\u200cمساحت ۹۰ متر مربع در روستای افراسیاب\u200cکلا به نیت ارائه خدمات بهداشتی به\u200cنام شهید مدافع حرم علی جمشیدی وقف عام شد که ارزش اعیانی احداثی ۳۰۰میلیون تومان برآورد شده است.\nصادقی خاطرنشان کرد: همچنین وقف ششدانگ اعیانی احداثی به\u200cمساحت ۱۱۰ متر مربع به ارزش ۴۰۰ میلیون تومان واقع در گلندرود رویان جهت استفاده و استقرار مرکز اورژانس فوریت\u200cهای پزشکی به\u200cنام شهید مرتضی دیلمقانی شد.\nگفتنی است، واقف خیراندیش محمد چراغی پیش از این مجتمع عروس دریا و چند طبقه ساختمان مسکونی با نیت نگهداری و تامین هزینه کودکان بی\u200cسرپرست و بدسرپرست را وقف کرده بود.\nبه گزارش فارس، واقف خیراندیش محمد چراغی یکی از بزرگترین واقفان و خیران کشور به شمار می\u200cرود که در ساخت کتابخانه، مدرسه و خانه محروم اقدامات ماندگاری دارد و از سوی رئیس سازمان اوقاف و امور خیریه مورد تجلیل قرار گرفته است.\nپایان پیام/۸۶۰۴۸/م',
#   'categories': ['social'],
#   'ner_tags': [{'type': 'FAC', 'entity': 'خانه بهداشت'},
#    {'type': 'GPE', 'entity': 'نور'},
#    {'type': 'POST', 'entity': 'رئیس اداره اوقاف و امور خیریه شهرستان نور'},
#    {'type': 'PER', 'entity': 'محمد چراغی'},
#    {'type': 'GPE', 'entity': 'نور'},
#    {'type': 'ORG', 'entity': 'خانه بهداشت'},
#    {'type': 'ORG', 'entity': 'مرکز اورژانس'},
#    {'type': 'EVE', 'entity': 'هفته'},
#    {'type': 'PER', 'entity': 'بهزاد صادقی'},
#    {'type': 'JOB', 'entity': 'خبرنگار فارس'},
#    {'type': 'GPE', 'entity': 'شهرستان نور'},
#    {'type': 'EVE', 'entity': 'هفته وقف'},
#    {'type': 'PER', 'entity': 'محمد چراغی'},
#    {'type': 'GPE', 'entity': 'روستای افراسیاب\u200cکلا'},
#    {'type': 'PER', 'entity': 'علی جمشیدی'},
#    {'type': 'PER', 'entity': 'صادقی'},
#    {'type': 'GPE', 'entity': 'گلندرود رویان'},
#    {'type': 'ORG', 'entity': 'مرکز اورژانس فوریت\u200cهای پزشکی'},
#    {'type': 'PER', 'entity': 'مرتضی دیلمقانی'},
#    {'type': 'PER', 'entity': 'محمد چراغی'},
#    {'type': 'ORG', 'entity': 'فارس'},
#    {'type': 'PER', 'entity': 'واقف خیراندیش'},
#    {'type': 'PER', 'entity': 'محمد چراغی'},
#    {'type': 'POST', 'entity': 'رئیس سازمان اوقاف و امور خیریه'}]},
#  {'body': 'پایان هفته آسمان چهارمحال بختیاری صاف قسمتی ابری گاهی افزایش ابر وزش باد پار نقاط غبار رقیق صبحگاهی بینی بنا اعلام اداره هواشناسی چهارمحال بختیاری اساس بررسی نقشه یابی هواشناسی پایان هفته آسمان استان صاف قسمتی ابری گاهی افزایش ابر وزش باد پار نقاط غبار رقیق صبحگاهی بینی ساعات ظهر خصوصا روز چهارشنبه افزایش ابر افزایش سرعت وزش باد خیزش گرد خاک صورت محلی نفوذ غبار انتظار میرود بخوانیدبرای روز پایانی هفته مناطق بخصوص ارتفاعات شمال استان بارش پراکنده انتظار',
#   'image_title_url': 'https://cdn.yjc.ir/files/fa/news/1402/7/18/18390743_715.jpg',
#   'language': 'fa',
#   'source': 'خبرگزاری باشگاه خبرنگاران | آخرین اخبار ایران و جهان | YJC',
#   'title': 'پیش بینی آسمانی صاف تا قسمتی ابری برای چهارمحال و بختیاری',
#   'date_published': 1696909710,
#   'uid': '1c79364ff8bf8a8fa096246a2',
#   'url': 'http://www.yjc.ir/fa/news/8568063',
#   'crawler_timestamp': 1696910161,
#   'ingestor_timestamp': 1696925867,
#   'summary': 'تا پایان هفته آسمان چهارمحال و بختیاری صاف تا قسمتی ابری گاهی با افزایش ابر، وزش باد و در پاره\u200cای نقاط با غبار رقیق صبحگاهی پیش بینی می\u200cشود.',
#   'hostname': 'yjc.ir',
#   'parser_categories': ['شهرکرد'],
#   'keywords': ['اداره هواشناسی چهارمحال بختیاری',
#    'چهارمحال بختیاری',
#    'هواشناسی'],
#   'parser_keyword': ['وضعیت هوا', 'افزایش ابر'],
#   'author': 'خبرگزاری باشگاه خبرنگاران; آخرین اخبار ایران و جهان; YJC',
#   'processed_body': 'بنا بر اعلام اداره کل هواشناسی چهارمحال و بختیاری و بر اساس بررسی آخرین نقشه\u200cهای پیش یابی هواشناسی تا پایان هفته آسمان استان صاف تا قسمتی ابری گاهی با افزایش ابر، وزش باد و در پاره\u200cای نقاط با غبار رقیق صبحگاهی پیش بینی می\u200cشود.\n\nبرای ساعات بعد از ظهر خصوصا از روز چهارشنبه افزایش ابر، افزایش سرعت وزش باد، خیزش گرد و خاک به صورت محلی و نفوذ غبار انتظار می\u200cرود.\n\nبیشتر بخوانید\n\nبرای روز\u200cهای پایانی هفته در برخی مناطق بخصوص ارتفاعات شمال استان بارش پراکنده دور از انتظار نیست.',
#   'categories': ['social'],
#   'ner_tags': [{'type': 'GPE', 'entity': 'چهارمحال و بختیاری'},
#    {'type': 'GPE', 'entity': 'چهارمحال و بختیاری'},
#    {'type': 'ORG', 'entity': 'اداره کل هواشناسی چهارمحال و بختیاری'}],
#   'cluster_id': 'd55219a8689a11ee810b921aaa64929e'},
#  {'body': 'فیلم Maria هنرنمایی آنجلینا جولی حول محور مشهورترین خواننده اپرای یونانی آمریکایی میباشد تصاویر منتشر ماریا کالاس میتوان مشهورترین خواننده زن اپرای جهان خطاب محدوده صدای سوپرانوی مخاطبی وجد آورده گذشت چندین مرگ موسیقی آلبومش جزو پرفروشترین آثار ژانر مختص خودمحسوب مسئل خالق فیلم Spencer اسپنسر پابلو لارائین مجاب دست ساخت فیلم بیوگرافی هنرنمایی آنجلینا جولی بزند فیلم Maria ماریا نام سال پایانی زندگی فراز نشیب جنجالی ماریا کالاس میپردازد مقطعی تجربه عشقی نافرجام افسردگی تنی قدم برداشت نت تسلیم درد رنجی توسط معشوقهاش متحمل گشته عارضه قلبی سال فانی وداع تصاویر فیلم انتظار منتشر آنجلینا جولی نقش آفرینی متفاوتی نشان میدهد میتوانید ادامه مشاهده بپردازید',
#   'image_title_url': 'https://gamefa.com/wp-content/uploads/2023/10/Maria.jpg',
#   'language': 'fa',
#   'source': 'freedownload.ir',
#   'title': 'هنرنمایی آنجلینا جولی در قامت مشهورترین خواننده اپرا جهان در فیلم Maria + انتشار نخستین تصاویر',
#   'date_published': 1696909802,
#   'uid': '5110de54dae55a6f8f7c3ed0a',
#   'url': 'https://www.freedownload.ir/news/game/61479-%D9%87%D9%86%D8%B1%D9%86%D9%85%D8%A7%DB%8C%DB%8C-%D8%A2%D9%86%D8%AC%D9%84%DB%8C%D9%86%D8%A7-%D8%AC%D9%88%D9%84%DB%8C-%D8%AF%D8%B1-%D9%82%D8%A7%D9%85%D8%AA-%D9%85%D8%B4%D9%87%D9%88%D8%B1%D8%AA%D8%B1%DB%8C%D9%86-%D8%AE%D9%88%D8%A7%D9%86%D9%86%D8%AF%D9%87-%D8%A7%D9%BE%D8%B1%D8%A7-%D8%AC%D9%87%D8%A7%D9%86-%D8%AF%D8%B1-%D9%81%DB%8C%D9%84%D9%85-maria-%D8%A7%D9%86%D8%AA%D8%B4%D8%A7%D8%B1-%D9%86%D8%AE%D8%B3%D8%AA%DB%8C%D9%86-%D8%AA%D8%B5%D8%A7%D9%88%DB%8C%D8%B1.html',
#   'crawler_timestamp': 1696928576,
#   'ingestor_timestamp': 1696943613,
#   'summary': 'اخبار تکنولوژی و اخبار بازی همراه با معرفی نرم افزار و برنامه، بازی، اندروید و انیمیشن',
#   'hostname': 'www.freedownload.ir',
#   'parser_categories': [],
#   'keywords': ['انیمیشن فیلم Maria', 'آنجلینا جولی', 'سال', 'فیلم Maria'],
#   'parser_keyword': ['خبرخوان',
#    'نرم افزار',
#    'رایگان',
#    'برنامه',
#    'بازی',
#    'دانلود رایگان',
#    'دانلود بازی',
#    'دانلود برنامه',
#    'اندروید',
#    'اخبار'],
#   'author': '',
#   'processed_body': 'فیلم Maria با هنرنمایی آنجلینا جولی حول محور مشهورترین خواننده اپرای یونانی-آمریکایی می\u200cباشد که نخستین تصاویر آن منتشر شده است.\n\nماریا کالاس را می\u200cتوان مشهورترین خواننده زن اپرای جهان خطاب کرد که با محدوده صدای سوپرانوی خود هر مخاطبی را به وجد آورده و با گذشت چندین دهه از مرگ وی، موسیقی و آلبوم\u200cهایش هنوز جزو پرفروش\u200cترین آثار ژانر مختص به خودمحسوب می\u200cشود. مسئله\u200cای که خالق فیلم Spencer (اسپنسر) یعنی پابلو لارائین را مجاب کرده تا دست به ساخت فیلم بیوگرافی وی با هنرنمایی آنجلینا جولی بزند.\n\nاین فیلم که Maria (ماریا) نام دارد، به سال\u200cهای پایانی زندگی پر فراز و نشیب و جنجالی ماریا کالاس می\u200cپردازد. مقطعی که او پس از تجربه عشقی نافرجام، به سمت افسردگی و تنهایی قدم برداشت و در نهایت نیز تسلیم درد و رنج\u200cهایی شد که توسط معشوقه\u200cاش به وی متحمل گشته بود و بر اثر عارضه قلبی در سال ۱۹۷۷ دار فانی را وداع گفت.\n\nحال نیز نخستین تصاویر از این فیلم مورد انتظار منتشر شده که آنجلینا جولی را در نقش آفرینی بسیار متفاوتی به ما نشان می\u200cدهد و می\u200cتوانید در ادامه به مشاهده آن بپردازید.',
#   'categories': ['economy'],
#   'ner_tags': [{'type': 'PER', 'entity': 'آنجلینا جولی'},
#    {'type': 'JOB', 'entity': 'خواننده اپرا'},
#    {'type': 'WOA', 'entity': 'فیلم Maria'},
#    {'type': 'WOA', 'entity': 'فیلم Maria'},
#    {'type': 'PER', 'entity': 'آنجلینا جولی'},
#    {'type': 'JOB', 'entity': 'خواننده اپرای یونانی'},
#    {'type': 'NORP', 'entity': 'آمریکایی'},
#    {'type': 'PER', 'entity': 'ماریا کالاس'},
#    {'type': 'JOB', 'entity': 'خواننده'},
#    {'type': 'WOA', 'entity': 'فیلم Spencer ( اسپنسر'},
#    {'type': 'PER', 'entity': 'پابلو لارائین'},
#    {'type': 'WOA', 'entity': 'فیلم'},
#    {'type': 'PER', 'entity': 'آنجلینا جولی'},
#    {'type': 'PER', 'entity': 'Maria'},
#    {'type': 'PER', 'entity': 'ماریا'},
#    {'type': 'PER', 'entity': 'ماریا کالاس'},
#    {'type': 'DATE', 'entity': 'سال ۱۹۷۷'},
#    {'type': 'PER', 'entity': 'آنجلینا جولی'}]},
#  {'body': 'رئیسجمهور اوکراین نگران پول توجه حامیان غربیاش معطوف اسرائیل ادعای حملات رژیم صهیونیستی مطرح گزارش گروه بینالملل خبرگزاری فارس ولودیمیر زلنسکی رئیسجمهور اوکراین نگران پول توجه حامیان غربیاش معطوف رژیم صهیونیستی عملیات نیرو مقاومت فلسطین تئوری توطئه ادعای مطرح پیامی مدعی دادهی وضوح ثابت میکند روسیه برانگیختن جنگ خاورمیانه علاقهمند یه طوری منبع جدیدی درد رنج وحدت جهانی ببرد شکافها مناقشات تشدید روسیه بردن آزادی اروپا کمک ادامه ادعا میتوانیم تبلیغگران روس ببینیم خوشحالی میکنند میتوانیم دوستان ایرانی مسکو ببینیم آشکارا دست یاری اسرائیل حمله دراز میکنند اینها تهدیدی بزرگتر جهان حاضر آگاه نشان میدهد جنگ جهانی گذشته توسط تجاوزات محلی آغاز پیشتر عملیات طوفان الاقصی نیرو مقاومت فلسطین موضع جامعه بینالمللی خواست نظاره گر حملات تروریستی نباشند شنبه آغاز عملیات حمایت صهیونیستها محکوم نیرو مقاومت فلسطین موضع زلنسکی پیشتر تاکید حق مسلم رژیم صهیونیستی دفاع جزئیات حمله تروریستی فاش جهان حمله حمایت انجام کمک بشناسد پاسخگو طوفان الاقصی سرزمین اشغالی موجی واکنشها همراه حمایتی کشور مسلمان حقوق مردم فلسطین همدردی حامیان رژیم صهیونیستی رژیم تأکید مجدد مقامات آمریکایی اسرائیل میمانند پایان پیام م',
#   'image_title_url': 'https://media.farsnews.ir/Uploaded/Files/Images/1402/07/18/14020718000197_Test_PhotoN.jpg',
#   'language': 'fa',
#   'source': 'خبرگزاری فارس',
#   'title': 'خبرگزاری فارس - ادعای زلنسکی: روسیه علاقه مند به برانگیختن جنگ در خاورمیانه است',
#   'date_published': 1696909834,
#   'uid': '87b218ce3b0ac72d379358268',
#   'url': 'https://www.farsnews.ir/news/14020718000228/ادعای-زلنسکی-روسیه-علاقه\u200cمند-به-برانگیختن-جنگ-در-خاورمیانه-است',
#   'crawler_timestamp': 1696910044,
#   'ingestor_timestamp': 1696925868,
#   'summary': 'رئیس\u200cجمهور اوکراین نگران از این که پول و توجه حامیان غربی\u200cاش معطوف اسرائیل شود، ادعاهایی را در خصوص حملات اخیر به رژیم صهیونیستی مطرح کرد.',
#   'hostname': 'farsnews.ir',
#   'parser_categories': ['بین الملل - آمریکا، اروپا'],
#   'keywords': ['رئیس جمهور اوکراین',
#    'رژیم صهیونیستی',
#    'طوفان الاقصی',
#    'مقاومت فلسطین'],
#   'parser_keyword': ['اوکراین', 'ولودیمیر زلنسکی', 'فلسطین'],
#   'author': 'خبرگزاری فارس',
#   'processed_body': 'به گزارش گروه بین\u200cالملل خبرگزاری فارس، «ولودیمیر زلنسکی» رئیس\u200cجمهور اوکراین نگران از این که پول و توجه حامیان غربی\u200cاش معطوف رژیم صهیونیستی در پی عملیات اخیر نیروهای مقاومت فلسطین شود، به تئوری توطئه روی آورد و ادعاهایی را مطرح کرد.\nاو در پیامی مدعی شد: «داده\u200cهایی داریم که به وضوح ثابت می\u200cکند روسیه به برانگیختن جنگ در خاورمیانه علاقه\u200cمند است. یه طوری که منبع جدیدی از درد و رنج وحدت جهانی را از بین ببرد و شکاف\u200cها و مناقشات را تشدید کند و به روسیه در از بین بردن آزادی در اروپا کمک کند».\nوی در ادامه ادعاهای خود گفت: «می\u200cتوانیم تبلیغ\u200cگران روس را ببینیم که خوشحالی می\u200cکنند. می\u200cتوانیم دوستان ایرانی مسکو را ببینیم که آشکارا دست یاری برای کسانی که به اسرائیل حمله کردند دراز می\u200cکنند. همه اینها تهدیدی بسیار بزرگتر از آنچه جهان در حال حاضر از آن آگاه است را نشان می\u200cدهد. جنگ\u200cهای جهانی گذشته توسط تجاوزات محلی آغاز شد».\nاو پیش\u200cتر هم علیه عملیات «طوفان الاقصی» نیروهای مقاومت فلسطین موضع گرفت و از جامعه بین\u200cالمللی خواست، نظاره گر «این حملات تروریستی» نباشند.\nاو شنبه در آغاز عملیات هم در حمایت از صهیونیست\u200cها و محکوم کردن نیروهای مقاومت فلسطین موضع گرفته بود. زلنسکی پیش\u200cتر با تاکید بر حق مسلم رژیم صهیونیستی برای «دفاع از خود» گفته بود: «تمام جزئیات مربوط به این حمله تروریستی باید فاش شود تا جهان همه کسانی که از این حمله حمایت و برای انجام آن کمک کردند را بشناسد و پاسخگو کند».\nطوفان الاقصی در سرزمین\u200cهای اشغالی موجی از واکنش\u200cها را به همراه داشته، از حمایت\u200cهایی که کشورهای مسلمان از حقوق مردم فلسطین داشتند تا همدردی حامیان رژیم صهیونیستی از این رژیم و تاکید مجدد مقامات آمریکایی بر اینکه در کنار اسرائیل می\u200cمانند.\nپایان پیام/م',
#   'categories': ['politics'],
#   'ner_tags': [{'type': 'PER', 'entity': 'زلنسکی'},
#    {'type': 'GPE', 'entity': 'روسیه'},
#    {'type': 'GPE', 'entity': 'خاورمیانه'},
#    {'type': 'POST', 'entity': 'رئیس\u200cجمهور اوکراین'},
#    {'type': 'NORP', 'entity': 'غربی\u200cاش'},
#    {'type': 'ORG', 'entity': 'اسرائیل'},
#    {'type': 'ORG', 'entity': 'رژیم صهیونیستی'},
#    {'type': 'ORG', 'entity': 'گروه بین\u200cالملل خبرگزاری فارس'},
#    {'type': 'PER', 'entity': 'ولودیمیر زلنسکی'},
#    {'type': 'POST', 'entity': 'رئیس\u200cجمهور اوکراین'},
#    {'type': 'NORP', 'entity': 'غربی\u200cاش'},
#    {'type': 'ORG', 'entity': 'رژیم صهیونیستی'},
#    {'type': 'NORP', 'entity': 'مقاومت فلسطین'},
#    {'type': 'GPE', 'entity': 'روسیه'},
#    {'type': 'GPE', 'entity': 'خاورمیانه'},
#    {'type': 'GPE', 'entity': 'روسیه'},
#    {'type': 'GPE', 'entity': 'اروپا'},
#    {'type': 'NORP', 'entity': 'روس'},
#    {'type': 'NORP', 'entity': 'ایرانی'},
#    {'type': 'GPE', 'entity': 'مسکو'},
#    {'type': 'ORG', 'entity': 'اسرائیل'},
#    {'type': 'EVE', 'entity': 'طوفان الاقصی'},
#    {'type': 'NORP', 'entity': 'مقاومت فلسطین'},
#    {'type': 'NORP', 'entity': 'صهیونیست\u200cها'},
#    {'type': 'NORP', 'entity': 'مقاومت فلسطین'},
#    {'type': 'PER', 'entity': 'زلنسکی'},
#    {'type': 'ORG', 'entity': 'رژیم صهیونیستی'},
#    {'type': 'EVE', 'entity': 'طوفان الاقصی'},
#    {'type': 'NORP', 'entity': 'مسلمان'},
#    {'type': 'GPE', 'entity': 'فلسطین'},
#    {'type': 'ORG', 'entity': 'رژیم صهیونیستی'},
#    {'type': 'NORP', 'entity': 'آمریکایی'},
#    {'type': 'ORG', 'entity': 'اسرائیل'}]},
#  {'body': 'مدیرکل امور فرآورده طبیعی سنتی مکمل سازمان غذا دارو تولیدات کارخانجات داخلی شیرخشک روزانه کشور توزیع محموله شیر خشک وارداتی صورت فوریتی حمل هفته کشور خواهد گزارش گروه سلامت خبرگزاری فارس منوچهر دادگرنژاد تامین شیرخشک رگولار اظهار حاضر مشکلی تامین شیرخشک توجه تامین فرآورده مسیر تولید داخل واردات زودی بازار مرتفع خواهد عنوان تولیدکنندگان شیرخشک ظرفیت تامین بازار تولیدات روزانه کشور توزیع مدیر امور فرآورده طبیعی سنتی مکمل سازمان غذا دارو برنامه توزیع شیرخشک استان اساس الگوی مصرف سال میزان موالید سال صورت ماهانه بازنگری هدف اصلی تامین شیرخشک کشور روان فرآیند توزیع مقابله قاچاق فرآورده غذایی دادگرنژاد پایان دست اندرکاران زنجیره تامین فرآورده ها صورت شبانه روزی همگام سازمان جهت رفع مصرف همکاری تقدیر پایان پیام',
#   'image_title_url': 'https://media.farsnews.ir/Uploaded/Files/Images/1402/04/19/14020419000826_Test_PhotoN.jpg',
#   'language': 'fa',
#   'source': 'خبرگزاری فارس',
#   'title': 'خبرگزاری فارس - محموله های شیر خشک وارداتی وارد کشور خواهد شد',
#   'date_published': 1696909841,
#   'uid': '837d37a4906f6fb14f43cc81f',
#   'url': 'https://www.farsnews.ir/news/14020718000313/محموله\u200cهای-شیر-خشک-وارداتی-وارد-کشور-خواهد-شد',
#   'crawler_timestamp': 1696910052,
#   'ingestor_timestamp': 1696925868,
#   'summary': 'مدیرکل امور فرآورده\u200cهای طبیعی، سنتی و مکمل سازمان غذا و دارو گفت: تولیدات کارخانجات داخلی شیرخشک روزانه در کشور توزیع می\u200cشود و محموله\u200cهای شیر خشک وارداتی به صورت فوریتی حمل و طی هفته\u200cهای پیش رو وارد کشور خواهد شد.<br/>',
#   'hostname': 'farsnews.ir',
#   'parser_categories': ['جامعه - سلامت'],
#   'keywords': ['سازمان غذا دارو', 'منوچهر دادگرنژاد', 'دادگرنژاد'],
#   'parser_keyword': ['شیر خشک', 'کمبود شیرخشک', 'واردات شیر'],
#   'author': 'خبرگزاری فارس',
#   'processed_body': 'به گزارش گروه سلامت خبرگزاری فارس، منوچهر دادگرنژاد در خصوص تامین شیرخشک\u200c رگولار اظهار کرد: در حال حاضر مشکلی از لحاظ تامین شیرخشک وجود ندارد و\xa0با توجه به تامین این فرآورده از مسیر تولید داخل و واردات، به زودی نیاز بازار مرتفع خواهد شد.\nوی عنوان کرد: تولیدکنندگان شیرخشک با تمام ظرفیت در حال تامین بازار هستند و تولیدات آنها روزانه در کشور توزیع می\u200cشود.\nمدیر کل امور فرآورده\u200cهای طبیعی، سنتی و مکمل سازمان غذا و دارو خاطرنشان کرد: برنامه توزیع شیرخشک مورد نیاز هر استان\u200c بر اساس الگوی مصرف سال ۱۴۰۱ ، میزان موالید سال جاری و نیاز تعیین و به صورت ماهانه بازنگری می\u200cشود.\nوی افزود: هدف اصلی ما تامین شیرخشک مورد نیاز کشور، روان شدن فرآیند توزیع و البته مقابله با قاچاق این فرآورده مهم غذایی است.\nدادگرنژاد در پایان از تمامی دست اندرکاران زنجیره تامین فرآورده ها که به صورت شبانه روزی همگام با این سازمان در جهت رفع نیاز مصرف کنندگان همکاری کرده اند، تقدیر کرد.\nپایان پیام/',
#   'categories': ['social'],
#   'ner_tags': [{'type': 'POST',
#     'entity': 'مدیرکل امور فرآورده\u200cهای طبیعی، سنتی و مکمل سازمان غذا و دارو'},
#    {'type': 'ORG', 'entity': 'گروه سلامت خبرگزاری فارس'},
#    {'type': 'PER', 'entity': 'منوچهر دادگرنژاد'},
#    {'type': 'JOB', 'entity': 'تولیدکنندگان'},
#    {'type': 'POST',
#     'entity': 'مدیر کل امور فرآورده\u200cهای طبیعی ، سنتی و مکمل سازمان غذا و دارو'},
#    {'type': 'PER', 'entity': 'دادگرنژاد'}],
#   'cluster_id': 'd552344c689a11ee810b921aaa64929e'},
#   'processed_body': 'محمد ارزنده رکوردار سابق پرش طول ایران در خصوص حمایت از رشته\u200cهای ورزشی پایه گفت: انتظار است از ورزشکاران رشته\u200cهای پایه مانند دوومیدانی که می\u200cتوانند بیشترین مدال\u200cها را در بازی\u200cهایی آسیایی و المپیک کسب کنند، مانند رشته فوتبال حمایت مالی و امکاناتی شوند.\n\nوی افزود: این همه به رشته ورزشی فوتبال بها داده می\u200cشود، کاش به رشته\u200cهای پایه از جمله دوومیدانی نیز پرداخته می\u200cشد و سوال اینجاست که چرا وقتی یک دونده سهمیه المپیک و جهانی دریافت می\u200cکند، به اندازه ورزشکاران فوتبال از او حمایت نمی\u200cشود.\n\nقهرمان سابق دوومیدانی با اشاره به کسب سهمیه المپیک خود گفت: در حالی که پاداش فوتبالیست\u200cها برای ورود به بازی\u200cهای جهانی چندین برابر ورزشکاران رشته\u200cهای دیگر است، برای دریافت سهمیه المپیک ۱۰ میلیون ریال (یک میلیون تومان) پاداش گرفتم که در مقابل رشته فوتبال بسیار بسیار ناچیز بود.\n\nبیشتر بخوانید\n\nارزنده که دارای رکورد بالای هشت متر در پرش طول ایران است، گفت: کاروان ورزشی ایران در هانگژو را باید کیفی بررسی کرد و اینکه علت اعزام تیم فوتبال با مربیان و چندین نفر کادر چه بوده است؟ در حالی که رشته\u200cهایی مانند دوومیدانی با هشت ورزشکار دومدال طلا و نقره را کسب کردند.\n\nوی اظهار کرد: بودجه کمیته ملی المپیک با وجود بازی\u200cهای آسیایی هانگژو در سالجاری و المپیک سال آینده در مقایسه با فوتبال که موفق به صعود به المپیک نشد و در بازی\u200cهای آسیایی نیز حذف شد، ناچیز است.\n\nارزنده ادامه داد: وقتی برای ورزشکار اعتبار مناسب نیست نباید انتظار مدال از ورزشکاران نخبه کشور در برابر رقبایی که بیشترین سرمایه\u200cگذاری و هزینه\u200cها را دارند، داشته باشند.\n\nوی گفت: اگر از ورزشکاران قهرمان پیش از رقابت\u200cهای المپیک، جهانی و آسیایی حمایت نشود بعد از پایان رقابت\u200cها نیز ورزشکاران دلسرد می\u200cشوند و نمی\u200cتوانند برای نسل بعدی الگوی کسب مدال باشد.\n\nرکوردار سابق پرش طول ایران و نایب قهرمان آسیا با بیان اینکه برای بررسی شاخص\u200cهای قهرمانی باید هر دوره مسابقات آسیایی را با دوره قبل خود مقایسه کرد گفت: برای کسب مدال در بازی\u200cهای آسیایی باید حداقل از دوسال قبل\u200cتر برنامه\u200cریزی کرد و آماده شد؛ مانند ورزشکار دونده چینی که برای مسابقات آسیایی امسال نیامد تا بتواند برای المپیک ۲۰۲۴ پاریس خود را آماده کند و این نشان از برنامه\u200cریزی و آینده\u200cنگری برای کسب مدال است.\n\nارزنده اظهار کرد: باید برای ورزشکاران در هر دوره از رقابت\u200cها شرایطی ایجاد شود که هم ورزشکار و هم مربیان بتوانند برای کسب استعداد\u200cهای هر رشته، برنامه بلند مدت داشته باشند و ورزشکار پس از یک شکست در رقابت\u200cها از ورزش قهرمانی کنار نرود.',
#   'categories': ['sports'],
#   'ner_tags': [{'type': 'POST', 'entity': 'ورزشکاران'},
#    {'type': 'POST', 'entity': 'قهرمان سابق دوومیدانی'},
#    {'type': 'GPE', 'entity': 'چهارمحال و بختیاری'},
#    {'type': 'GPE', 'entity': 'ایران'},
#    {'type': 'PER', 'entity': 'محمد ارزنده رکوردار'},
#    {'type': 'POST', 'entity': 'سابق پرش طول ایران'},
#    {'type': 'POST', 'entity': 'ورزشکاران'},
#    {'type': 'EVE', 'entity': 'آسیایی'},
#    {'type': 'POST', 'entity': 'دونده'},
#    {'type': 'EVE', 'entity': 'المپیک و جهانی'},
#    {'type': 'POST', 'entity': 'ورزشکاران'},
#    {'type': 'POST', 'entity': 'قهرمان سابق دوومیدانی'},
#    {'type': 'POST', 'entity': 'ورزشکاران'},
#    {'type': 'GPE', 'entity': 'ایران'},
#    {'type': 'ORG', 'entity': 'کاروان ورزشی ایران'},
#    {'type': 'GPE', 'entity': 'هانگژو'},
#    {'type': 'ORG', 'entity': 'تیم فوتبال'},
#    {'type': 'POST', 'entity': 'مربیان'},
#    {'type': 'POST', 'entity': 'ورزشکار'},
#    {'type': 'ORG', 'entity': 'کمیته ملی المپیک'},
#    {'type': 'EVE', 'entity': 'بازی\u200cهای آسیایی هانگژو'},
#    {'type': 'EVE', 'entity': 'بازی\u200cهای آسیایی'},
#    {'type': 'PER', 'entity': 'ارزنده'},
#    {'type': 'POST', 'entity': 'ورزشکار'},
#    {'type': 'POST', 'entity': 'ورزشکاران'},
#    {'type': 'POST', 'entity': 'ورزشکاران'},
#    {'type': 'EVE', 'entity': 'رقابت\u200cهای'},
#    {'type': 'EVE', 'entity': 'المپیک ، جهانی و آسیایی'},
#    {'type': 'POST', 'entity': 'ورزشکاران'},
#    {'type': 'POST', 'entity': 'رکوردار'},
#    {'type': 'GPE', 'entity': 'ایران'},
#    {'type': 'POST', 'entity': 'نایب قهرمان آسیا'},
#    {'type': 'EVE', 'entity': 'مسابقات آسیایی'},
#    {'type': 'EVE', 'entity': 'بازی\u200cهای آسیایی'},
#    {'type': 'POST', 'entity': 'ورزشکار'},
#    {'type': 'POST', 'entity': 'دونده چینی'},
#    {'type': 'EVE', 'entity': 'مسابقات آسیایی'},
#    {'type': 'EVE', 'entity': 'المپیک ۲۰۲۴ پاریس'},
#    {'type': 'PER', 'entity': 'ارزنده'},
#    {'type': 'POST', 'entity': 'ورزشکاران'},
#    {'type': 'POST', 'entity': 'ورزشکار'},
#    {'type': 'POST', 'entity': 'ورزشکار'}]},
#  {'body': 'گزارش ایسنا مهدی اسلام پناه خبری اظهار بحث کمفروشی دستگاهی سازمان استاندارد مسئولیت اوزان سال گذشته اعلام کردیم میزان کمفروشی درصد حاضر رقم درصد کاهش شاخص کیفیت کالا زودی رونمایی همکاری دانشگاه شریف شاخصها بررسی استانها حوزه قلم کالا بررسی نشان میدهد خودرو دخانیات کمترین رضایت مردم اختصاص کالاها شویندهها رضایت سطح بینالمللی اسلام پناه اشاره جایگاه بیست ایران استاندارد جهانی پاسخ سوالی رابطه رجیستر آیفون اظهار انشااله کالا رجیستر خواهد گوشی تکنولوژی مشکلی موبایل مشمول استاندارد اجباری موضوع زیرمجموعه وزارت ارتباطات پول ذخیره زودی بتوانید آیفون بخرید',
#   'image_title_url': 'https://cdn.isna.ir/d/2022/08/14/4/62349328.jpg?ts=1660465649156',
#   'language': 'fa',
#   'source': 'ایسنا',
#   'title': 'رجیستر شدن آیفون ۱۴ به زودی/ مانع تراشی برای واردات خودرو دروغ محض است',
#   'date_published': 1696909923,
#   'uid': '5497ccaecdd45e198003e79a2',
#   'url': 'https://www.isna.ir/news/1402071812080/رجیستر-شدن-آیفون-۱۴-به-زودی-مانع-تراشی-برای-واردات-خودرو-دروغ',
#   'crawler_timestamp': 1696910005,
#   'ingestor_timestamp': 1696925868,
#   'summary': 'رئیس سازمان ملی استاندارد ضمن اشاره به اینکه در صورت کم شدن محدودیت ارزی و صلاح وزارت ارتباطات، آیفون ۱۴ رجیستر خواهد شد، درباره اینکه سازمان استاندارد متولی این امر نیست، توضیح داد: آیفون ۱۴ مشکل استاندارد ندارد.',
#   'hostname': 'isna.ir',
#   'parser_categories': ['اقتصادی > تولید و تجارت'],
#   'keywords': ['بیست ایران', 'آیفون', 'اسلام پناه', 'دانشگاه شریف'],
#   'parser_keyword': ['واردات خودرو',
#    'رجیستری',
#    'وزارت ارتباطات و فناوری اطلاعات',
#    'آیفون 14'],
#   'author': 'زهرا اکرمی',
#   'processed_body': 'به گزارش ایسنا، مهدی اسلام پناه در نشست خبری اظهار کرد: بحث کم\u200cفروشی بین دستگاهی است و سازمان استاندارد مسئولیت اوزان را دارد. سال گذشته اعلام کردیم میزان کم\u200cفروشی بیش از ۴۱ درصد است، اما در حال حاضر این رقم ۱۸.۵ درصد کاهش یافته است.\nوی با بیان اینکه شاخص\u200cهای کیفیت کالا به زودی رونمایی می\u200cشود، گفت: با همکاری دانشگاه شریف این شاخص\u200cها بررسی شده در همه استان\u200cها در حوزه ۵۶ قلم کالا بررسی شده که نشان می\u200cدهد خودرو و دخانیات کم\u200cترین رضایت مردم را به خود اختصاص داده و در مورد برخی کالاها مثل شوینده\u200cها نیز رضایت در سطح بین\u200cالمللی بوده است.\nاسلام پناه با اشاره به جایگاه بیست و دوم ایران در استاندارد جهانی، در پاسخ به سوالی در رابطه با پول ذخیره کنید که به زودی بتوانید آیفون ۱۴ بخرید. رجیستر شدن آیفون ۱۴ اظهار کرد: اگر محدویت\u200cهای ارزی کم شده و وزارت ارتباطات صلاح بداند این کالا در آینده رجیستر خواهد شد.\nادامه دارد...',
#   'categories': ['economy'],
#   'ner_tags': [{'type': 'ORG', 'entity': 'آیفون'},
#    {'type': 'POST', 'entity': 'رئیس سازمان ملی استاندارد'},
#    {'type': 'ORG', 'entity': 'وزارت ارتباطات'},
#    {'type': 'ORG', 'entity': 'آیفون'},
#    {'type': 'ORG', 'entity': 'سازمان استاندارد'},
#    {'type': 'ORG', 'entity': 'آیفون'},
#    {'type': 'ORG', 'entity': 'ایسنا'},
#    {'type': 'PER', 'entity': 'مهدی اسلام پناه'},
#    {'type': 'ORG', 'entity': 'سازمان استاندارد'},
#    {'type': 'FAC', 'entity': 'دانشگاه شریف'},
#    {'type': 'PER', 'entity': 'اسلام پناه'},
#    {'type': 'GPE', 'entity': 'ایران'},
#    {'type': 'ORG', 'entity': 'آیفون'},
#    {'type': 'ORG', 'entity': 'آیفون ۱۴'},
#    {'type': 'ORG', 'entity': 'وزارت ارتباطات'}],
#   'cluster_id': 'd552450e689a11ee810b921aaa64929e'},
#  {'body': 'پنجمین کنفرانس بینالمللی میکروالکترونیک ایران آبان ماه سالجاری دانشکده مهندسی برق دانشگاه صنعتی امیرکبیر برگزار گزارش ایسنا کنفرانس کنفرانس تخصصی زمینه میکروالکترونیک داخل کشور سال انجمن میکروالکترونیک ایران دانشگاه معتبر کشور رویکردی بینالمللی برگزار هدف برگزاری کنفرانس ایجاد محیطی پویا تبادل علمی ارائه دستاورد پژوهشی گسترش دانش فنی زمینه مختلف میکروالکترونیک چهره برجسته علمی پژوهشگران متخصصین صنعتگران مدیران محققان فعال زمینه موضوع کنفرانس حضور مدارها سیستم مجتمع آنالوگ سیگنال مخلوط مبدل مدارها سیستم مجتمع فرکانس رادیویی مدارها سیستم مجتمع دیجیتال مدارها افزاره مایکروویو موج میلیمتری مدارها افزاره مدیریت توان انرژی مدارها سیستمها افزاره الکترونیک زیستی مدارها افزاره الکترونیک نوری مدارها افزاره کوانتومی نمایشگرها مدارها سیستم تصویربرداری حسگرها افزاره میکرو نانو الکترومکانیکی فناوری ساخت بستهبندی افزارهها اطمینان پذیری مدارها افزارهها مدلسازی شبیهسازی مدارها افزارهها افزارهها مواد نوظهور الکترونیک مدارها سیستم گسترده الکترونیکی اقتصاد کسب کار میکروالکترونیک محور کنفرانس کنفرانس مقاله صورت سخنرانی ارائه خواهد مقالات علمی کارگاه آموزشی میزگرد تخصصی سخنرانی کلیدی انتخاب جهت ارائه برنامهریزی شدهاند نمایشگاهی دستاورد محققان حوزه صنعت میکروالکترونیک برگزار خواهد نقل روابط عمومی دانشگاه صنعتی امیرکبیر علاقهمندان پژوهش صنعت میکروالکترونیک میتوانند مختلف کنفرانس شرکت دستاورد علمی زمینه بهرهمند',
#   'image_title_url': 'https://cdn.isna.ir/d/2020/12/19/4/61806047.jpg',
#   'language': 'fa',
#   'source': 'ایسنا',
#   'title': 'دانشگاه امیرکبیر؛ میزبان پنجمین کنفرانس بین المللی میکروالکترونیک ایران',
#   'date_published': 1696909923,
#   'uid': '9337d28000d899408bb3b6722',
#   'url': 'https://www.isna.ir/news/1402071812129/دانشگاه-امیرکبیر-میزبان-پنجمین-کنفرانس-بین-المللی-میکروالکترونیک',
#   'crawler_timestamp': 1696910055,
#   'ingestor_timestamp': 1696925868,
#   'summary': 'پنجمین کنفرانس بین\u200cالمللی میکروالکترونیک ایران، ۳ و ۴ آبان ماه سال\u200cجاری در دانشکده مهندسی برق دانشگاه صنعتی امیرکبیر برگزار می\u200cشود.',
#   'hostname': 'isna.ir',
#   'parser_categories': ['علمی و دانشگاهی > علم و فناوری ایران'],
#   'keywords': ['دانشکده مهندسی برق دانشگاه صنعتی امیرکبیر',
#    'کنفرانس المللی میکروالکترونیک ایران',
#    'انجمن میکروالکترونیک ایران',
#    'دانشگاه صنعتی امیرکبیر'],
#   'parser_keyword': ['دانشگاه اميركبير', 'ميكروالكترونيك'],
#   'author': 'دبیر رقیه السادات حسینی',
#   'processed_body': 'به گزارش ایسنا،\nاین کنفرانس تنها کنفرانس تخصصی در زمینه میکروالکترونیک در داخل کشور بوده و هر سال تحت نظر انجمن میکروالکترونیک ایران در یکی از دانشگاه\u200cهای معتبر کشور با رویکردی بین\u200cالمللی برگزار می\u200cشود.\nهدف از برگزاری این کنفرانس، ایجاد محیطی پویا برای تبادل نظر علمی، ارائه آخرین دستاوردهای پژوهشی و گسترش دانش فنی در زمینه\u200cهای مختلف میکروالکترونیک است و در آن چهره\u200cهای برجسته علمی، پژوهشگران، متخصصین، صنعتگران، مدیران و محققان فعال در زمینه\u200cهای موضوع کنفرانس حضور دارند.\nمدارها و سیستم\u200cهای مجتمع آنالوگ و سیگنال مخلوط، مبدل\u200cهای داده، مدارها و سیستم\u200cهای مجتمع فرکانس رادیویی، مدارها و سیستم\u200cهای مجتمع دیجیتال، مدارها و افزاره\u200cهای مایکروویو و موج میلی\u200cمتری، مدارها و افزاره\u200cهای مدیریت توان و انرژی، مدارها، سیستم\u200cها و افزاره\u200cهای الکترونیک زیستی، مدارها و افزاره\u200cهای الکترونیک نوری، مدارها و افزاره\u200cهای کوانتومی، نمایشگرها، مدارها و سیستم\u200cهای تصویربرداری، حسگرها و افزاره\u200cهای میکرو و نانو الکترومکانیکی، فناوری\u200cهای ساخت و بسته\u200cبندی افزاره\u200cها، اطمینان پذیری در مدارها و افزاره\u200cها، مدل\u200cسازی و شبیه\u200cسازی مدارها و افزاره\u200cها، افزاره\u200cها و مواد نوظهور در الکترونیک، مدارها و سیستم\u200cهای گسترده الکترونیکی و اقتصاد و کسب و کار میکروالکترونیک از محورهای این کنفرانس است.\nدر این کنفرانس ۵۶ مقاله در ۱۰ نشست به صورت سخنرانی ارائه خواهد شد.\nعلاوه بر مقالات علمی، ۶ کارگاه آموزشی، ۲ میزگرد تخصصی و ۳ سخنرانی کلیدی انتخاب و جهت ارائه برنامه\u200cریزی شده\u200cاند. همچنین\xa0نمایشگاهی از آخرین دستاوردهای محققان حوزه صنعت میکروالکترونیک برگزار خواهد شد.\nبه نقل از\xa0روابط عمومی دانشگاه صنعتی امیرکبیر،\xa0تمام علاقه\u200cمندان به پژوهش و صنعت میکروالکترونیک می\u200cتوانند در بخش\u200cهای مختلف کنفرانس شرکت کنند و از آخرین دستاوردهای علمی در این زمینه بهره\u200cمند شوند.\nانتهای پیام',
#   'categories': ['economy'],
#   'ner_tags': [{'type': 'FAC', 'entity': 'دانشگاه امیرکبیر'},
#    {'type': 'EVE',
#     'entity': 'پنجمین کنفرانس بین\u200cالمللی میکروالکترونیک ایران'},
#    {'type': 'EVE',
#     'entity': 'پنجمین کنفرانس بین\u200cالمللی میکروالکترونیک ایران، ۳'},
#    {'type': 'FAC', 'entity': 'دانشکده مهندسی برق دانشگاه صنعتی امیرکبیر'},
#    {'type': 'ORG', 'entity': 'ایسنا'},
#    {'type': 'ORG', 'entity': 'انجمن میکروالکترونیک ایران'},
#    {'type': 'POST', 'entity': 'پژوهشگران'},
#    {'type': 'JOB', 'entity': 'صنعتگران'},
#    {'type': 'POST', 'entity': 'مدیران'},
#    {'type': 'POST', 'entity': 'محققان'},
#    {'type': 'ORG', 'entity': 'روابط عمومی دانشگاه صنعتی امیرکبیر'}]},
#  {'body': 'گزارش باشگاه دانشجویان ایسنا فلسفی مهر ماه ساعت الی سخنرانی دکتر هادی صمدی ـ عضو هیئت علمی دانشگاه آزاد اسلامی واحد علوم تحقیقات بهصورت آنلاین برگزار علاقهمندان میتوانند جهت شرکت برنامه لینک https vc isu ac ir ch theology sci assn مراجعه پزشکی مبتنی شواهد استفاده عاقلانه صریح آگاهانه شواهد موجود تصمیمگیری مراقبت پزشکی بیماران معنای طبابت مبتنی شواهد عبارت ادغام تجربه بالینی پزشک شواهد بالینی دسترس بیرونی پژوهش نظاممند بهدست میآید تجربه بالینی چیرگی قضاوتی پزشکان شکل طریق تجربه طبابت بالینی بهدست میآوردند افزایش تجربه موارد انعکاس مییابد تشخیص موثرتر کارآمدتر شناسایی هوشمندانه مشفقانه معضلات حقوق ترجیحات بیماران تصمیمگیری بالینی مراقبت نشان میدهد',
#   'image_title_url': 'https://cdn.isna.ir/d/2023/10/09/4/62758822.jpg?ts=1696854918726',
#   'language': 'fa',
#   'source': 'ایسنا',
#   'title': 'نگاه تکاملی به پزشکی مبتنی بر شواهد',
#   'date_published': 1696909923,
#   'uid': '29cf32170839299276be24a6c',
#   'url': 'https://www.isna.ir/news/1402071812121/نگاه-تکاملی-به-پزشکی-مبتنی-بر-شواهد',
#   'crawler_timestamp': 1696909976,
#   'ingestor_timestamp': 1696925868,
#   'summary': 'انجمن علمی الهیات و معارف اسلامی دانشگاه امام صادق (ع)، نشست «نگاه تکاملی به پزشکی مبتنی بر شواهد» از سلسله نشست\u200cهای فلسفی را برگزار می\u200cکند.',
#   'hostname': 'isna.ir',
#   'parser_categories': ['باشگاه دانشجویان > انجمن های علمی'],
#   'keywords': ['عضو هیئت علمی دانشگاه آزاد اسلامی واحد علوم تحقیقات',
#    'انجمن علمی الهیات معارف اسلامی دانشگاه امام صادق',
#    'هادی صمدی'],
#   'parser_keyword': ['باشگاه دانشجویان ایسنا',
#    'انجمن علمی الهیات و معارف اسلامی دانشگاه امام صادق (ع)',
#    'نگاه تکاملی به پزشکی مبتنی بر شواهد'],
#   'author': 'فاطمه ولیپور',
#   'processed_body': 'به گزارش باشگاه دانشجویان ایسنا، این نشست فلسفی ۲۰ مهر ماه ساعت ۱۵ الی ۱۷، با سخنرانی دکتر هادی صمدی ـ عضو هیئت علمی دانشگاه آزاد اسلامی واحد علوم و تحقیقات، به\u200cصورت آنلاین برگزار می\u200cشود.\nعلاقه\u200cمندان می\u200cتوانند جهت شرکت در این برنامه به لینک https://vc.isu.ac.ir/ch/theology-sci-assn مراجعه کنند.\nپزشکی مبتنی بر شواهد استفاده\u200c عاقلانه، صریح و آگاهانه از بهترین شواهد موجود در امر تصمیم\u200cگیری برای مراقبت\u200cهای پزشکی از فرد فرد بیماران است. معنای طبابت مبتنی بر شواهد عبارت است از\xa0 ادغام تجربه بالینی شخصی پزشک با بهترین شواهد بالینی در دسترس بیرونی که از پژوهش\u200cهای نظام\u200cمند به\u200cدست می\u200cآید.\nمنظور از تجربه بالینی فردی، چیرگی و قضاوتی است که پزشکان به شکل فردی از طریق تجربه و طبابت بالینی به\u200cدست می\u200cآوردند. افزایش تجربه در موارد زیادی انعکاس می\u200cیابد، اما به خصوص خودش را در تشخیص موثرتر و کارآمدتر و همچنین در شناسایی هوشمندانه و لحاظ کردن مشفقانه معضلات، حقوق، و ترجیحات بیماران در تصمیم\u200cگیری بالینی در مورد مراقبت از آنها نشان می\u200cدهد.\nانتهای پیام',
#   'categories': ['culture'],
#   'ner_tags': [{'type': 'ORG',
#     'entity': 'انجمن علمی الهیات و معارف اسلامی دانشگاه امام صادق (ع)'},
#    {'type': 'EVE', 'entity': 'نشست «نگاه تکاملی به پزشکی مبتنی بر شواهد»'},
#    {'type': 'ORG', 'entity': 'باشگاه دانشجویان ایسنا'},
#    {'type': 'EVE', 'entity': 'نشست'},
#    {'type': 'PER', 'entity': 'هادی صمدی'},
#    {'type': 'POST',
#     'entity': 'عضو هیئت علمی دانشگاه آزاد اسلامی واحد علوم و تحقیقات'},
#    {'type': 'JOB', 'entity': 'پزشک'},
#    {'type': 'JOB', 'entity': 'پزشکان'}]},
#  {'body': 'ایسنا کرمانشاه سرپرست شرکت گاز استان کرمانشاه اشاره سرما بارشی هفته گذشته کرمانشاه شاهد بودیم وضعیت مصرف گاز صورت زودهنگام میزان درصد برد ناصر حسینی گو ایسنا پاییز امسال زودهنگام بارش تبع سرمای هوا شاهد بودیم اظهار مصرف گاز استان کرمانشاه درصد افزایش میلیون مترمکعب روز میلیون مترمکعب روز برسد میزان احتساب مصرف صنایع چنانچه افزایش مصرف ادامه پیک سرما ناچار اعمال محدودیت صنایع استان هدف تامین گاز خانگی خواهیم سرپرست شرکت گاز استان کرمانشاه میزان پیک مصرف گاز روز سرد سال گذشته استان احتساب صنایع میلیون مترمکعب روز اعلام پیشبینی میزان امسال درصد حسینی میزان افزایش مصرف گاز متاثر رفتار مشترکین دمای هوا افزایش هزار موردی مشترکین نادیده بگیریم افزایش مصرف گاز دامن خواهد زد مشترکین گاز خواست پایداری تامین گاز حتما صرفهجویی مصرف مد ادامه بستن دریچه کولر پوشاندن درز درب پنجرهها استفاده لباس گرم نپوشاندن اطراف سیستم گرمایشی رعایت دمای آسایش جمله راهکار صرفه جویی مصرف گاز',
#   'image_title_url': 'https://cdn.isna.ir/d/2023/08/21/4/62705173.jpg?ts=1692594613466',
#   'language': 'fa',
#   'source': 'ایسنا',
#   'title': 'سرمای زودهنگام پاییزی مصرف گاز کرمانشاه را ۴۰ درصد افزایش داد',
#   'date_published': 1696909923,
#   'uid': '78a1b366a87f861afa30ae8da',
#   'url': 'https://www.isna.ir/news/1402071812131/سرمای-زودهنگام-پاییزی-مصرف-گاز-کرمانشاه-را-۴۰-درصد-افزایش-داد',
#   'crawler_timestamp': 1696910050,
#   'ingestor_timestamp': 1696925868,
#   'summary': 'سرپرست شرکت گاز استان کرمانشاه با اشاره به سرما و بارشی که طی هفته گذشته در کرمانشاه شاهد بودیم، گفت: این وضعیت مصرف گاز را به صورت زودهنگام به میزان ۴۰ درصد بالا برد.',
#   'hostname': 'isna.ir',
#   'parser_categories': ['استان ها > کرمانشاه'],
#   'keywords': ['سرپرست شرکت گاز استان کرمانشاه',
#    'ناصر حسینی',
#    'حسینی',
#    'کرمانشاه'],
#   'parser_keyword': ['استانی-اقتصادی', 'كرمانشاه', 'گاز', 'مصرف گاز'],
#   'author': 'فاطمه کمانی',
#   'processed_body': 'ناصر حسینی در گفت و گو با ایسنا، با بیان اینکه در پاییز امسال شروع زودهنگام بارش و به تبع آن سرمای هوا را شاهد بودیم، اظهار کرد: این امر باعث شد مصرف گاز در استان کرمانشاه حدود ۴۰ درصد افزایش یافته و از حدود ۳.۵ میلیون مترمکعب در روز به پنج میلیون مترمکعب در روز برسد.\nوی با بیان اینکه این میزان بدون احتساب مصرف صنایع بزرگ است، افزود: چنانچه روند افزایش مصرف ادامه یابد، در پیک سرما ناچار به اعمال محدودیت برای صنایع بزرگ استان با هدف تامین گاز بخش خانگی خواهیم بود.\nسرپرست شرکت گاز استان کرمانشاه میزان پیک مصرف گاز در روزهای سرد سال گذشته در استان را بدون احتساب صنایع بزرگ حدود ۲۱ میلیون مترمکعب در روز اعلام و پیش\u200cبینی کرد این میزان امسال ۱۰ تا ۱۵ درصد بیشتر شود.\nحسینی میزان افزایش مصرف گاز را متاثر از رفتار مشترکین و همچنین دمای هوا دانست و خاطرنشان کرد: البته نباید افزایش ۲۰ تا ۲۵ هزار موردی مشترکین را نادیده بگیریم که این امر نیز خود به افزایش مصرف گاز دامن خواهد زد.\nوی از مشترکین گاز خواست برای پایداری تامین گاز حتما صرفه\u200cجویی در مصرف را مد نظر داشته باشند و ادامه داد: بستن دریچه\u200cهای کولر، پوشاندن درز درب و پنجره\u200cها، استفاده از لباس گرم، نپوشاندن اطراف سیستم\u200cهای گرمایشی، رعایت دمای آسایش و... از جمله راهکارهای صرفه جویی در مصرف گاز است.\nانتهای پیام',
#   'categories': ['economy'],
#   'ner_tags': [{'type': 'GPE', 'entity': 'کرمانشاه'},
#    {'type': 'POST', 'entity': 'سرپرست شرکت گاز استان کرمانشاه'},
#    {'type': 'GPE', 'entity': 'کرمانشاه'},
#    {'type': 'PER', 'entity': 'ناصر حسینی'},
#    {'type': 'ORG', 'entity': 'ایسنا'},
#    {'type': 'GPE', 'entity': 'کرمانشاه'},
#    {'type': 'POST', 'entity': 'سرپرست شرکت گاز استان کرمانشاه'},
#    {'type': 'PER', 'entity': 'حسینی'}]},
#  {'body': 'ایسنا خراسان شمالی نایب رئیس شورای اسلامی شهر بجنورد مرکز کنترل ترافیک موارد مهمی مرکز استان ایجاد علی اربابی مهر یکصد سومین جلسه رسمی شورای اسلامی شهر بجنورد سالن جلسات مجموعه برگزار نطق دستور اظهار مرکز کنترل ترافیک جزو نیازمندی اولویت شهر بجنورد مرکز استان ایجاد طرح مطالعات جامع حمل نقل ترافیک شهری بجنورد بهروزرسانی لزوم بهروزرسانی مطالعات جامع حمل نقل ترافیک شهری تاکید اقدامات توسعه نوسازی ناوگان حمل نقل عمومی ایم نگاه زیرساختی شورای اسلامی شهر بجنورد همراهی اعضای شورای اسلامی شهر شهرداری بجنورد محقق تقدیر اربابی پیگیری توسعه زیرساختی ساختمان سازگار محیط زیست ساختمان سبز حضور مشاور طرح برگزاری جلسات روز خبر ساختمان ها مشخصه صرفه جویی انرژی مبحث ساخته نیازمند راهکار راهبردی اجرایی مشوق ی مدیریت شهری دستگاه مرتبط فعالان عرصه مشتاق ساخت ساختمان سبز سید محسن موسوی عضو هیأت رئیسه شورای اسلامی شهر بجنورد نطق دستور اشاره اطلس سرمایه پیوست جذب سرمایه منطقه ای اشتغال آفرینی تقویت سرانه ها شهری بجنورد رقابت پذیری اقتصاد گردشگری اقتصاد سلامت رویکرد انحصاری تاکید خواستار مولد املاک شهری ارتباط پذیری راستای بهبود شاخص رفاه اجتماعی ادامه قرائت نامه رسیده مصوبات کمیسیون تخصصی شورای اسلامی شهر بجنورد مصوبات کمیسیون توافقات شهرداری بجنورد اقدام گفتنی یکصد سومین جلسه رسمی شورای اسلامی شهر بجنورد صورت علنی غیرعلنی برگزار',
#   'image_title_url': 'https://cdn.isna.ir/d/2023/10/10/4/62759291.jpg?ts=1696919910163',
#   'language': 'fa',
#   'source': 'ایسنا',
#   'title': 'راه اندازی مرکز کنترل ترافیک از اولویت های مهم بجنورد است',
#   'date_published': 1696909923,
#   'uid': 'c4eaa6025745b6a1e67c4b13d',
#   'url': 'https://www.isna.ir/news/1402071812139/راه-اندازی-مرکز-کنترل-ترافیک-از-اولویت-های-مهم-بجنورد-است',
#   'crawler_timestamp': 1696910027,
#   'ingestor_timestamp': 1696925868,
#   'summary': 'نایب رئیس شورای اسلامی شهر بجنورد، مرکز کنترل ترافیک را یکی از موارد مهمی دانست که باید در مرکز استان ایجاد شود.',
#   'hostname': 'isna.ir',
#   'parser_categories': ['استان ها > خراسان شمالی'],
#   'keywords': ['طرح مطالعات جامع حمل نقل ترافیک شهری',
#    'شورای اسلامی شهر بجنورد',
#    'ناوگان حمل نقل',
#    'شورای اسلامی شهر'],
#   'parser_keyword': ['خراسان شمالی',
#    'استانی-شهرستانها',
#    'شورای اسلامی شهر بجنورد',
#    'شهرداری بجنورد',
#    'کنترل ترافیک'],
#   'author': 'سید پوریا مسلمی',
#   'processed_body': 'علی اربابی ۱۸ مهر در یکصد و سی و سومین جلسه رسمی شورای اسلامی شهر بجنورد که در سالن جلسات این مجموعه برگزار شد، در نطق پیش از دستور خود اظهار کرد: مرکز کنترل ترافیک جزو نیازمندی های اولویت دار شهر بجنورد است که باید در مرکز استان ایجاد شود، همچنین طرح مطالعات جامع حمل و نقل و ترافیک شهری بجنورد نیز باید به\u200cروزرسانی شود.\nوی بر لزوم به\u200cروزرسانی مطالعات جامع حمل و نقل و ترافیک شهری تاکید کرد و افزود: اقدامات خوبی در توسعه و نوسازی ناوگان حمل و نقل عمومی داشته ایم و این نگاه زیرساختی در شورای اسلامی شهر بجنورد که با همراهی اعضای شورای اسلامی شهر و شهرداری بجنورد محقق شده است جای تقدیر دارد.\nاربابی همچنین از پیگیری روند توسعه زیرساختی ساختمان های سازگار با محیط زیست (ساختمان سبز) با حضور مشاور طرح و برگزاری جلسات طی روزهای پیش رو خبر داد و گفت: این ساختمان ها با مشخصه صرفه جویی در انرژی و مبحث ۱۹ ساخته می شوند که نیازمند راهکارهای راهبردی، اجرایی و مشوق هایی از سوی مدیریت شهری و دستگاه\u200cهای مرتبط هستیم تا فعالان این عرصه مشتاق به ساخت ساختمان های سبز شوند.\nسید محسن موسوی عضو هیات رئیسه شورای اسلامی شهر بجنورد نیز در نطق پیش از دستور خود با اشاره به اطلس سرمایه گذاری در پیوست های جذب سرمایه گذاری منطقه ای، بر اشتغال آفرینی و تقویت سرانه ها و نیاز شهری بجنورد در رقابت پذیری بر اقتصاد گردشگری و اقتصاد سلامت با رویکرد انحصاری تاکید کرد و خواستار مولد سازی املاک شهری و ارتباط پذیری در راستای بهبود شاخص های رفاه اجتماعی شد.\nدر ادامه نسبت به قرائت نامه های رسیده، مصوبات کمیسیون های تخصصی شورای اسلامی شهر بجنورد و مصوبات کمیسیون توافقات شهرداری بجنورد اقدام شد.\nگفتنی است یکصد و سی و سومین جلسه رسمی شورای اسلامی شهر بجنورد در دو بخش و به صورت علنی و غیرعلنی برگزار شد.\nانتهای پیام',
#   'categories': ['economy'],
#   'ner_tags': [{'type': 'ORG', 'entity': 'مرکز کنترل ترافیک'},
#    {'type': 'GPE', 'entity': 'بجنورد'},
#    {'type': 'POST', 'entity': 'نایب رئیس شورای اسلامی شهر بجنورد'},
#    {'type': 'ORG', 'entity': 'مرکز کنترل ترافیک'},
#    {'type': 'PER', 'entity': 'علی اربابی'},
#    {'type': 'EVE',
#     'entity': 'یکصد و سی و سومین جلسه رسمی شورای اسلامی شهر بجنورد'},
#    {'type': 'GPE', 'entity': 'بجنورد'},
#    {'type': 'LAW',
#     'entity': 'طرح مطالعات جامع حمل و نقل و ترافیک شهری بجنورد'},
#    {'type': 'ORG', 'entity': 'ناوگان حمل و نقل عمومی'},
#    {'type': 'ORG', 'entity': 'شورای اسلامی شهر بجنورد'},
#    {'type': 'POST', 'entity': 'اعضای شورای اسلامی شهر'},
#    {'type': 'ORG', 'entity': 'شهرداری بجنورد'},
#    {'type': 'PER', 'entity': 'اربابی'},
#    {'type': 'POST', 'entity': 'مشاور طرح'},
#    {'type': 'PER', 'entity': 'محسن موسوی'},
#    {'type': 'POST', 'entity': 'عضو هیات رئیسه شورای اسلامی شهر بجنورد'},
#    {'type': 'GPE', 'entity': 'بجنورد'},
#    {'type': 'ORG', 'entity': 'کمیسیون\u200cهای تخصصی شورای اسلامی شهر بجنورد'},
#    {'type': 'ORG', 'entity': 'کمیسیون توافقات شهرداری بجنورد'},
#    {'type': 'EVE',
#     'entity': 'یکصد و سی و سومین جلسه رسمی شورای اسلامی شهر بجنورد'}]}]

# %%
# according to desmose curve on "https://www.desmos.com/calculator/hwtd8h8hdx"  I think, these parameters are good choices.
r=8
b=40
m=r*b
s=.6
shi=7

# %% [markdown]
# # STEP1 : SHINGLING

# %%
def shingling(text, k): 
    shingles = set()
    for i in range(0, len(text)-k+1 ):
        shingles.add(text[i:i+k])
    return shingles

# %%
body = cleaned.take(1)[0]['body']
body
# Out:
# 'سرمربی ملوان تصاویر وایرالی دیدار نساجی پست جالب منتشر گزارش ورزش مهدی تارتار خوشحالی عجیب غریب دقیقه چهره جالب هفته لیگ برتر اختصاص موردتوجه هواداران فوتبال قرار تارتار انتشار پست اینستاگرامی تصاویر جشن خوشحالی نوشته جادوی طرفداران انزلی سرمربی ملوان وعده تیمش ادامه فصل توان خواهد جنگید رضایت هواداران جلب نوشته ادامه میخوانید عکسها نگاه میکنم متحیر میشوم یادم نمیآید هرگز اینطور شوری باشم جادوی شماست سکو آنچنان حس انرژی میدهید لحظه پیروزی برایمان وصفناشدنی سکوها لب خط پای تلویزیونها مستطیل سبز همدل یکصدا میرویم باهم میجنگیم باهم میخندیم هرروز تلاش میکنیم خنده صورت نگه پیروزی شماست مردان نیک چمن مردمان نیک سکو \U0001fa75🤍'

# %%
news_data_shingled= cleaned.map(lambda x : (x['uid'],x['body']))\
.map(lambda x: (x[0], shingling(x[1],shi)))

# %%
news_data_shingled.take(1)
# Out:
# [('68feae4bbbedc2d54adbb2369',
#   {' آنچنان',
#    ' اختصاص',
#    ' ادامه ',
#    ' انتشار',
#    ' انرژی ',
#    ' انزلی ',
#    ' اینستا',
#    ' اینطور',
#    ' باشم ج',
#    ' باهم م',
#    ' برایما',
#    ' برتر ا',
#    ' تارتار',
#    ' تصاویر',
#    ' تلاش م',
#    ' تلویزی',
#    ' توان خ',
#    ' تیمش ا',
#    ' جادوی ',
#    ' جالب م',
#    ' جالب ه',
#    ' جشن خو',
#    ' جلب نو',
#    ' جنگید ',
#    ' حس انر',
#    ' خط پای',
#    ' خنده ص',
#    ' خواهد ',
#    ' خوشحال',
#    ' دقیقه ',
#    ' دیدار ',
#    ' رضایت ',
#    ' سبز هم',
#    ' سرمربی',
#    ' سکو آن',
#    ' سکو \U0001fa75🤍',
#    ' سکوها ',
#    ' شماست ',
#    ' شوری ب',
#    ' صورت ن',
#    ' طرفدار',
#    ' عجیب غ',
#    ' عکسها ',
#    ' غریب د',
#    ' فصل تو',
#    ' فوتبال',
#    ' قرار ت',
#    ' لب خط ',
#    ' لحظه پ',
#    ' لیگ بر',
#    ' متحیر ',
#    ' مردان ',
#    ' مردمان',
#    ' مستطیل',
#    ' ملوان ',
#    ' منتشر ',
#    ' مهدی ت',
#    ' موردتو',
#    ' میجنگی',
#    ' میخندی',
#    ' میخوان',
#    ' میدهید',
#    ' میرویم',
#    ' میشوم ',
#    ' میکنم ',
#    ' میکنیم',
#    ' نساجی ',
#    ' نمیآید',
#    ' نوشته ',
#    ' نگاه م',
#    ' نگه پی',
#    ' نیک سک',
#    ' نیک چم',
#    ' هرروز ',
#    ' هرگز ا',
#    ' هفته ل',
#    ' همدل ی',
#    ' هوادار',
#    ' وایرال',
#    ' ورزش م',
#    ' وصفناش',
#    ' وعده ت',
#    ' پای تل',
#    ' پست ای',
#    ' پست جا',
#    ' پیروزی',
#    ' چمن مر',
#    ' چهره ج',
#    ' گزارش ',
#    ' یادم ن',
#    ' یکصدا ',
#    'آنچنان ',
#    'آید هرگ',
#    'ا لب خط',
#    'ا مستطی',
#    'ا میروی',
#    'ا نگاه ',
#    'اجی پست',
#    'اختصاص ',
#    'اداران ',
#    'ادامه ف',
#    'ادامه م',
#    'ادم نمی',
#    'ادوی شم',
#    'ادوی طر',
#    'ار انتش',
#    'ار تارت',
#    'ار خوشح',
#    'ار نساج',
#    'ار پست ',
#    'اران ان',
#    'اران جل',
#    'اران فو',
#    'ارتار ا',
#    'ارتار خ',
#    'ارش ورز',
#    'است سکو',
#    'است مرد',
#    'اش میکن',
#    'اشدنی س',
#    'اشم جاد',
#    'اص مورد',
#    'ال قرار',
#    'الب منت',
#    'الب هفت',
#    'الی دید',
#    'الی عجی',
#    'الی نوش',
#    'امه فصل',
#    'امه میخ',
#    'امی تصا',
#    'ان انزل',
#    'ان تصاو',
#    'ان جلب ',
#    'ان حس ا',
#    'ان خواه',
#    'ان فوتب',
#    'ان نیک ',
#    'ان وصفن',
#    'ان وعده',
#    'انتشار ',
#    'انرژی م',
#    'انزلی س',
#    'انید عک',
#    'اه میکن',
#    'اهد جنگ',
#    'اهم میج',
#    'اهم میخ',
#    'اویر جش',
#    'اویر وا',
#    'اگرامی ',
#    'ای تلوی',
#    'ایت هوا',
#    'ایرالی ',
#    'ایمان و',
#    'اینستاگ',
#    'اینطور ',
#    'ب خط پا',
#    'ب دقیقه',
#    'ب غریب ',
#    'ب منتشر',
#    'ب نوشته',
#    'ب هفته ',
#    'باشم جا',
#    'بال قرا',
#    'باهم می',
#    'برایمان',
#    'برتر اخ',
#    'بز همدل',
#    'بی ملوا',
#    'ت اینست',
#    'ت جالب ',
#    'ت سکو آ',
#    'ت مردان',
#    'ت نگه پ',
#    'ت هوادا',
#    'تار انت',
#    'تار خوش',
#    'تارتار ',
#    'تاگرامی',
#    'تبال قر',
#    'تحیر می',
#    'تر اختص',
#    'تشار پس',
#    'تشر گزا',
#    'تصاص مو',
#    'تصاویر ',
#    'تطیل سب',
#    'تلاش می',
#    'تلویزیو',
#    'ته ادام',
#    'ته جادو',
#    'ته لیگ ',
#    'توان خو',
#    'توجه هو',
#    'تیمش اد',
#    'جادوی ش',
#    'جادوی ط',
#    'جالب من',
#    'جالب هف',
#    'جشن خوش',
#    'جلب نوش',
#    'جنگید ر',
#    'جنگیم ب',
#    'جه هواد',
#    'جی پست ',
#    'جیب غری',
#    'حالی عج',
#    'حالی نو',
#    'حس انرژ',
#    'حظه پیر',
#    'حیر میش',
#    'ختصاص م',
#    'خط پای ',
#    'خنده صو',
#    'خندیم ه',
#    'خوانید ',
#    'خواهد ج',
#    'خوشحالی',
#    'د جنگید',
#    'د رضایت',
#    'د عکسها',
#    'د لحظه ',
#    'د هرگز ',
#    'دا میرو',
#    'دار نسا',
#    'داران ا',
#    'داران ج',
#    'داران ف',
#    'دامه فص',
#    'دامه می',
#    'دان نیک',
#    'دتوجه ه',
#    'دقیقه چ',
#    'دل یکصد',
#    'دم نمیآ',
#    'دمان نی',
#    'دنی سکو',
#    'ده تیمش',
#    'ده صورت',
#    'دهید لح',
#    'دوی شما',
#    'دوی طرف',
#    'دی تارت',
#    'دیدار ن',
#    'دیم هرر',
#    'ر اختصا',
#    'ر انتشا',
#    'ر تارتا',
#    'ر جشن خ',
#    'ر خوشحا',
#    'ر شوری ',
#    'ر میشوم',
#    'ر نساجی',
#    'ر وایرا',
#    'ر پست ا',
#    'ر گزارش',
#    'رار تار',
#    'رالی دی',
#    'رامی تص',
#    'ران انز',
#    'ران جلب',
#    'ران فوت',
#    'رایمان ',
#    'ربی ملو',
#    'رت نگه ',
#    'رتار ان',
#    'رتار خو',
#    'رتر اخت',
#    'ردان نی',
#    'ردتوجه ',
#    'ردمان ن',
#    'رروز تل',
#    'رزش مهد',
#    'رش ورزش',
#    'رضایت ه',
#    'رفداران',
#    'رمربی م',
#    'ره جالب',
#    'روز تلا',
#    'روزی بر',
#    'روزی شم',
#    'رویم با',
#    'رژی مید',
#    'رگز این',
#    'ری باشم',
#    'ریب دقی',
#    'ز اینطو',
#    'ز تلاش ',
#    'ز همدل ',
#    'زارش ور',
#    'زش مهدی',
#    'زلی سرم',
#    'زی برای',
#    'زی شماس',
#    'زیونها ',
#    'س انرژی',
#    'ساجی پس',
#    'سبز همد',
#    'ست اینس',
#    'ست جالب',
#    'ست سکو ',
#    'ست مردا',
#    'ستاگرام',
#    'ستطیل س',
#    'سرمربی ',
#    'سها نگا',
#    'سکو آنچ',
#    'سکوها ل',
#    'ش ادامه',
#    'ش مهدی ',
#    'ش میکنی',
#    'ش ورزش ',
#    'شار پست',
#    'شته ادا',
#    'شته جاد',
#    'شحالی ع',
#    'شحالی ن',
#    'شدنی سک',
#    'شر گزار',
#    'شم جادو',
#    'شماست س',
#    'شماست م',
#    'شن خوشح',
#    'شوری با',
#    'شوم یاد',
#    'ص موردت',
#    'صاص مور',
#    'صاویر ج',
#    'صاویر و',
#    'صدا میر',
#    'صفناشدن',
#    'صل توان',
#    'صورت نگ',
#    'ضایت هو',
#    'ط پای ت',
#    'طرفدارا',
#    'طور شور',
#    'طیل سبز',
#    'ظه پیرو',
#    'عجیب غر',
#    'عده تیم',
#    'عکسها ن',
#    'غریب دق',
#    'فته لیگ',
#    'فداران ',
#    'فصل توا',
#    'فناشدنی',
#    'فوتبال ',
#    'قرار تا',
#    'قه چهره',
#    'قیقه چه',
#    'ل توان ',
#    'ل سبز ه',
#    'ل قرار ',
#    'ل یکصدا',
#    'لاش میک',
#    'لب خط پ',
#    'لب منتش',
#    'لب نوشت',
#    'لب هفته',
#    'لحظه پی',
#    'لوان تص',
#    'لوان وع',
#    'لویزیون',
#    'لی دیدا',
#    'لی سرمر',
#    'لی عجیب',
#    'لی نوشت',
#    'لیگ برت',
#    'م باهم ',
#    'م جادوی',
#    'م خنده ',
#    'م متحیر',
#    'م میجنگ',
#    'م میخند',
#    'م نمیآی',
#    'م هرروز',
#    'م یادم ',
#    'ماست سک',
#    'ماست مر',
#    'مان نیک',
#    'مان وصف',
#    'متحیر م',
#    'مدل یکص',
#    'مربی مل',
#    'مردان ن',
#    'مردمان ',
#    'مستطیل ',
#    'مش ادام',
#    'ملوان ت',
#    'ملوان و',
#    'من مردم',
#    'منتشر گ',
#    'مه فصل ',
#    'مه میخو',
#    'مهدی تا',
#    'موردتوج',
#    'می تصاو',
#    'میآید ه',
#    'میجنگیم',
#    'میخندیم',
#    'میخوانی',
#    'میدهید ',
#    'میرویم ',
#    'میشوم ی',
#    'میکنم م',
#    'میکنیم ',
#    'ن انزلی',
#    'ن تصاوی',
#    'ن جلب ن',
#    'ن حس ان',
#    'ن خواهد',
#    'ن خوشحا',
#    'ن فوتبا',
#    'ن مردما',
#    'ن نیک س',
#    'ن نیک چ',
#    'ن وصفنا',
#    'ن وعده ',
#    'ناشدنی ',
#    'نان حس ',
#    'نتشار پ',
#    'نتشر گز',
#    'نده صور',
#    'ندیم هر',
#    'نرژی می',
#    'نزلی سر',
#    'نساجی پ',
#    'نستاگرا',
#    'نطور شو',
#    'نم متحی',
#    'نمیآید ',
#    'نها مست',
#    'نوشته ا',
#    'نوشته ج',
#    'نچنان ح',
#    'نگاه می',
#    'نگه پیر',
#    'نگید رض',
#    'نگیم با',
#    'نی سکوه',
#    'نید عکس',
#    'نیم خند',
#    'نیک سکو',
#    'نیک چمن',
#    'ه ادامه',
#    'ه تیمش ',
#    'ه جادوی',
#    'ه جالب ',
#    'ه صورت ',
#    'ه فصل ت',
#    'ه لیگ ب',
#    'ه میخوا',
#    'ه میکنم',
#    'ه هوادا',
#    'ه پیروز',
#    'ه چهره ',
#    'ها لب خ',
#    'ها مستط',
#    'ها نگاه',
#    'هد جنگی',
#    'هدی تار',
#    'هرروز ت',
#    'هره جال',
#    'هرگز ای',
#    'هفته لی',
#    'هم میجن',
#    'هم میخن',
#    'همدل یک',
#    'هوادارا',
#    'هید لحظ',
#    'و آنچنا',
#    'واداران',
#    'وان تصا',
#    'وان خوا',
#    'وان وعد',
#    'وانید ع',
#    'واهد جن',
#    'وایرالی',
#    'وتبال ق',
#    'وجه هوا',
#    'ور شوری',
#    'ورت نگه',
#    'وردتوجه',
#    'ورزش مه',
#    'وری باش',
#    'وز تلاش',
#    'وزی برا',
#    'وزی شما',
#    'وشته اد',
#    'وشته جا',
#    'وشحالی ',
#    'وصفناشد',
#    'وعده تی',
#    'وم یادم',
#    'ونها مس',
#    'وها لب ',
#    'وی شماس',
#    'وی طرفد',
#    'ویر جشن',
#    'ویر وای',
#    'ویزیونه',
#    'ویم باه',
#    'پای تلو',
#    'پست این',
#    'پست جال',
#    'پیروزی ',
#    'چمن مرد',
#    'چنان حس',
#    'چهره جا',
#    'ژی میده',
#    'ک سکو \U0001fa75',
#    'ک چمن م',
#    'کسها نگ',
#    'کصدا می',
#    'کنم متح',
#    'کنیم خن',
#    'کو آنچن',
#    'کوها لب',
#    'گ برتر ',
#    'گاه میک',
#    'گرامی ت',
#    'گز اینط',
#    'گزارش و',
#    'گه پیرو',
#    'گید رضا',
#    'گیم باه',
#    'ی باشم ',
#    'ی برایم',
#    'ی تارتا',
#    'ی تصاوی',
#    'ی تلویز',
#    'ی دیدار',
#    'ی سرمرب',
#    'ی سکوها',
#    'ی شماست',
#    'ی طرفدا',
#    'ی عجیب ',
#    'ی ملوان',
#    'ی میدهی',
#    'ی نوشته',
#    'ی پست ج',
#    'یآید هر',
#    'یادم نم',
#    'یب دقیق',
#    'یب غریب',
#    'یت هواد',
#    'یجنگیم ',
#    'یخندیم ',
#    'یخوانید',
#    'ید رضای',
#    'ید عکسه',
#    'ید لحظه',
#    'ید هرگز',
#    'یدار نس',
#    'یدهید ل',
#    'یر جشن ',
#    'یر میشو',
#    'یر وایر',
#    'یرالی د',
#    'یروزی ب',
#    'یروزی ش',
#    'یرویم ب',
#    'یزیونها',
#    'یشوم یا',
#    'یقه چهر',
#    'یل سبز ',
#    'یم باهم',
#    'یم خنده',
#    'یم هررو',
#    'یمان وص',
#    'یمش ادا',
#    'ینستاگر',
#    'ینطور ش',
#    'یونها م',
#    'یک سکو ',
#    'یک چمن ',
#    'یکصدا م',
#    'یکنم مت',
#    'یکنیم خ',
#    'یگ برتر'})]

# %%
print ("number of shingles for each sample : "+str(len(news_data_shingled.take(1)[0][1])))
# Out:
# number of shingles for each sample : 582

# %%
all_shigle= news_data_shingled.map(lambda x: x[1])\
.flatMap(lambda x : x)\
.distinct()\
.collect()
len_unique = len(all_shigle)

# %%
len_unique
# Out:
# 1372986

# %% [markdown]
# # STEP 2: Minhash

# %%
indexes = list(range(1,len_unique+1))
pairs=zip(all_shigle,indexes)
dic_shingles = dict(pairs)
dic_shingles
# Out:
# {'ش مهدی ': 1,
#  ' عکسها ': 2,
#  'اص مورد': 3,
#  'ه چهره ': 4,
#  'آنچنان ': 5,
#  'ن نیک س': 6,
#  'دامه فص': 7,
#  'ورزش مه': 8,
#  'ان حس ا': 9,
#  'میآید ه': 10,
#  'لاش میک': 11,
#  'مان وصف': 12,
#  ' تلاش م': 13,
#  'دمان نی': 14,
#  'فناشدنی': 15,
#  'اران فو': 16,
#  'جشن خوش': 17,
#  'خواهد ج': 18,
#  'یونها م': 19,
#  'ران جلب': 20,
#  'ان تصاو': 21,
#  ' جادوی ': 22,
#  'ور شوری': 23,
#  'ی دیدار': 24,
#  'د لحظه ': 25,
#  'لب نوشت': 26,
#  'م باهم ': 27,
#  'تیمش اد': 28,
#  'جالب هف': 29,
#  'گه پیرو': 30,
#  'ی میدهی': 31,
#  'ست سکو ': 32,
#  'فته لیگ': 33,
#  'عده تیم': 34,
#  ' نمیآید': 35,
#  'ش ادامه': 36,
#  'تارتار ': 37,
#  'سرمربی ': 38,
#  'جلب نوش': 39,
#  'جیب غری': 40,
#  ' یادم ن': 41,
#  'ب دقیقه': 42,
#  'ار نساج': 43,
#  'رایمان ': 44,
#  'ردمان ن': 45,
#  'لوان وع': 46,
#  'شته ادا': 47,
#  'شته جاد': 48,
#  'اشدنی س': 49,
#  'م یادم ': 50,
#  'یر وایر': 51,
#  'نیک سکو': 52,
#  ' سکو آن': 53,
#  'ب نوشته': 54,
#  ' خواهد ': 55,
#  'صاویر ج': 56,
#  'ژی میده': 57,
#  ' شماست ': 58,
#  ' ورزش م': 59,
#  ' غریب د': 60,
#  'شوری با': 61,
#  'ه لیگ ب': 62,
#  'وان خوا': 63,
#  ' جلب نو': 64,
#  ' سکوها ': 65,
#  'رروز تل': 66,
#  'ره جالب': 67,
#  'کوها لب': 68,
#  'یگ برتر': 69,
#  'لی سرمر': 70,
#  'ر میشوم': 71,
#  'سکوها ل': 72,
#  'ب خط پا': 73,
#  ' میخندی': 74,
#  ' نیک سک': 75,
#  'لب منتش': 76,
#  'شدنی سک': 77,
#  'زی برای': 78,
#  'ب غریب ': 79,
#  'تلاش می': 80,
#  'یکصدا م': 81,
#  'ن انزلی': 82,
#  'یمش ادا': 83,
#  'صورت نگ': 84,
#  'ه ادامه': 85,
#  'ها نگاه': 86,
#  'یآید هر': 87,
#  'ی عجیب ': 88,
#  'سها نگا': 89,
#  ' نساجی ': 90,
#  ' نیک چم': 91,
#  'مردان ن': 92,
#  ' هفته ل': 93,
#  'هد جنگی': 94,
#  'نتشر گز': 95,
#  ' جشن خو': 96,
#  'ه میکنم': 97,
#  'دیم هرر': 98,
#  'ده صورت': 99,
#  'ار انتش': 100,
#  'الی عجی': 101,
#  'دهید لح': 102,
#  ' اینطور': 103,
#  'هدی تار': 104,
#  'لب خط پ': 105,
#  'کنم متح': 106,
#  'بز همدل': 107,
#  'باشم جا': 108,
#  'ی برایم': 109,
#  'نگید رض': 110,
#  ' فوتبال': 111,
#  'دی تارت': 112,
#  'ستطیل س': 113,
#  'زلی سرم': 114,
#  'حیر میش': 115,
#  'شماست م': 116,
#  'ل سبز ه': 117,
#  'هم میجن': 118,
#  ' تارتار': 119,
#  'تحیر می': 120,
#  'دا میرو': 121,
#  'میکنیم ': 122,
#  'ی ملوان': 123,
#  'ه هوادا': 124,
#  'ی سکوها': 125,
#  'مه فصل ': 126,
#  'نوشته ج': 127,
#  'ایرالی ': 128,
#  'اشم جاد': 129,
#  'بال قرا': 130,
#  'ز اینطو': 131,
#  'نستاگرا': 132,
#  ' ملوان ': 133,
#  'امی میر': 134,
#  'ر مییاب': 135,
#  'ه حضور ': 136,
#  'شوری رد': 137,
#  ' معصومی': 138,
#  'م ملی ا': 139,
#  'رحله سی': 140,
#  'ان ایرا': 141,
#  'اته کا ': 142,
#  'حله سید': 143,
#  'ور مییا': 144,
#  'م نوجوا': 145,
#  'اراتهکا': 146,
#  ' رده پا': 147,
#  'سب همرا': 148,
#  'کسب مدا': 149,
#  'قات انت': 150,
#  'افروغی ': 151,
#  ' سیدمحم': 152,
#  'گرم نوج': 153,
#  'ی میرون': 154,
#  'می میرو': 155,
#  'پارسامی': 156,
#  'رنز کیل': 157,
#  ' مسابقا': 158,
#  'ا مرحله': 159,
#  ' مدال م': 160,
#  'هرماه ت': 161,
#  'اهند شا': 162,
#  'اراته و': 163,
#  'ده سال ': 164,
#  'م ملی ح': 165,
#  'عصومی ب': 166,
#  'مدال بر': 167,
#  ' همراه ': 168,
#  'ی تیم م': 169,
#  ' ایران ': 170,
#  'ه انتخا': 171,
#  'ن سیدمح': 172,
#  'نا مرحل': 173,
#  'رم نوجو': 174,
#  'ی مرحله': 175,
#  'رش ایسن': 176,
#  'ه مرحله': 177,
#  'ابی مرح': 178,
#  'بی مرحل': 179,
#  'یسنا قم': 180,
#  'ابی تیم': 181,
#  ' رنکینگ': 182,
#  ' مهرماه': 183,
#  'ار کارا': 184,
#  'ن فرید ': 185,
#  'ل کسب ه': 186,
#  'تخابی م': 187,
#  'ملی حضو': 188,
#  'نوجوانا': 189,
#  'ومی برن': 190,
#  'قمی درخ': 191,
#  'ه مهرما': 192,
#  'ارسامیر': 193,
#  'ی مدال ': 194,
#  'ا قمی م': 195,
#  'یروند گ': 196,
#  ' نوجوان': 197,
#  'لی حضور': 198,
#  'رمهدی م': 199,
#  'نکینگ ک': 200,
#  'شایان ذ': 201,
#  'رات رنک': 202,
#  'کا قمی ': 203,
#  'لی استا': 204,
#  'ری رده ': 205,
#  'ایه مهر': 206,
#  'فروغی ب': 207,
#  ' نفرات ': 208,
#  'ته رده ': 209,
#  ' فرید م': 210,
#  'ان لرست': 211,
#  'نگ کارا': 212,
#  'ه رده پ': 213,
#  'ن لرستا': 214,
#  'لرستان ': 215,
#  'رگزار ک': 216,
#  'یدمحمدص': 217,
#  'یلوگرم ': 218,
#  'یه مرحل': 219,
#  'انان سی': 220,
#  'فق کسب ': 221,
#  'وانان ف': 222,
#  ' سنی پا': 223,
#  'نی محمو': 224,
#  'عودی گف': 225,
#  ' مبتنی ': 226,
#  'رحله حس': 227,
#  'مان گفت': 228,
#  'گوی ریا': 229,
#  'رنظامیا': 230,
#  'یت هماه': 231,
#  'نیها حق': 232,
#  'اهنگی م': 233,
#  'گیری گر': 234,
#  'ترش ادا': 235,
#  'زاری ار': 236,
#  'ان ولیع': 237,
#  ' اساس گ': 238,
#  'ر غزه م': 239,
#  'رایزنیه': 240,
#  'ین اساس': 241,
#  'شاه ارد': 242,
#  'دی روز ': 243,
#  'بدتر شر': 244,
#  'لیعهد س': 245,
#  'ی روز ش': 246,
#  'لات خود': 247,
#  'ایستاده': 248,
#  'فصل جام': 249,
#  'قدسات م': 250,
#  'ت توقف ': 251,
#  'دی عربس': 252,
#  'دامه را': 253,
#  'ط امنیت': 254,
#  'اهنگی ک': 255,
#  'امور خا': 256,
#  'تجمهوری': 257,
#  'حترام ق': 258,
#  'تگویی ت': 259,
#  'ی کشور ': 260,
#  ' عملیات': 261,
#  'س جمهور': 262,
#  'سترش دا': 263,
#  'یز سیست': 264,
#  'فتگو مح': 265,
#  'هماهنگی': 266,
#  'اکید گز': 267,
#  'ی مصر ع': 268,
#  'ردم حقو': 269,
#  'ارت امو': 270,
#  'ی نوار ': 271,
#  'ستان جل': 272,
#  'لله تما': 273,
#  'ن سلمان': 274,
#  'واستار ': 275,
#  'وقف درگ': 276,
#  'ر اوضاع': 277,
#  ' داخلی ': 278,
#  'ه خواست': 279,
#  'اشها جه': 280,
#  'ات طوفا': 281,
#  'ام قوان': 282,
#  ' آینده ': 283,
#  'رومیت م': 284,
#  'بشردوست': 285,
#  'عدالت ص': 286,
#  'انداز س': 287,
#  'سانی فل': 288,
#  'راهکاری': 289,
#  'فتگو اه': 290,
#  'گو اهمی': 291,
#  ' مبنای ': 292,
#  'لفنی ضر': 293,
#  'یتی انس': 294,
#  'تلفنی ر': 295,
#  ' درگیری': 296,
#  'ات تحری': 297,
#  'ین اعلا': 298,
#  'ید اساس': 299,
#  'مع مسئل': 300,
#  'ها انفج': 301,
#  'له حساس': 302,
#  'ستیابند': 303,
#  'وفان ال': 304,
#  'لسیسی ر': 305,
#  'ری بدتر': 306,
#  'سیستمات': 307,
#  'استا بن': 308,
#  'کیلات خ': 309,
#  'صدور بی': 310,
#  'ستلزم ت': 311,
#  'قدامات ': 312,
#  'د ولیعه': 313,
#  ' اشغالگ': 314,
#  'د عربی ': 315,
#  'ار برسن': 316,
#  ' خبرگزا': 317,
#  'محمد بن': 318,
#  'زه منطق': 319,
#  'بند عدا': 320,
#  'س جلوگی': 321,
#  'اعلام ع': 322,
#  'اکید وز': 323,
#  'سطینیها': 324,
#  'جامع مس': 325,
#  ' روز شن': 326,
#  'مصر زمی': 327,
#  'تر شرای': 328,
#  'رگیری گ': 329,
#  'لتی فلس': 330,
#  ' میدهد ': 331,
#  'ت تاکید': 332,
#  'یعهد سع': 333,
#  ' قوانین': 334,
#  ' ایستاد': 335,
#  'بی مسئل': 336,
#  'اری ارد': 337,
#  'مردم فل': 338,
#  'کند ریا': 339,
#  'ستماتیک': 340,
#  'رش محمد': 341,
#  'گزاری ا': 342,
#  'ر زمینه': 343,
#  'یاض بار': 344,
#  'گروه فل': 345,
#  'ست راست': 346,
#  'قه فلسط': 347,
#  'ای راهک': 348,
#  'فنی عبد': 349,
#  'دم فلسط': 350,
#  'فتگوی ت': 351,
#  'رگزاری ': 352,
#  'ت ملت ف': 353,
#  'یایستد ': 354,
#  'طین ادا': 355,
#  'ق تلاش ': 356,
#  'تنداری ': 357,
#  'مبنای ر': 358,
#  'افتمندا': 359,
#  'ضرورت ا': 360,
#  'سطین مب': 361,
#  'م قوانی': 362,
#  'ساس جلو': 363,
#  'ن جلوگی': 364,
#  'ش خبرگز': 365,
#  'کید گزا': 366,
#  'ینیها ح': 367,
#  ' امنیتی': 368,
#  'دستیابی': 369,
#  'ن میایس': 370,
#  ' جهت تو': 371,
#  'نه اعلا': 372,
#  'زنیها ه': 373,
#  'طق تلاش': 374,
#  'دف قرار': 375,
#  'سطین اد': 376,
#  'ستار تو': 377,
#  'ینی نیر': 378,
#  'سطینیان': 379,
#  'یسی رئی': 380,
#  'زاری رس': 381,
#  'تان سعو': 382,
#  'مود عبا': 383,
#  'مللی بش': 384,
#  'رائیلی ': 385,
#  'نطق تلا': 386,
#  'ه تماس ': 387,
#  'مینه اع': 388,
#  'لزم توق': 389,
#  'ش میکند': 390,
#  'واس گزا': 391,
#  'ن الاقص': 392,
#  'رائیل م': 393,
#  'شروع ای': 394,
#  'سطین تا': 395,
#  'مشروع ز': 396,
#  'حقوق مش': 397,
#  'ک مقدسا': 398,
#  'گو محمو': 399,
#  'اش توقف': 400,
#  ' مستلزم': 401,
#  'دسات مس': 402,
#  'جهت تاک': 403,
#  ' ضرورت ': 404,
#  'یافتن چ': 405,
#  'ری فلسط': 406,
#  'نفجار ا': 407,
#  'بی راهک': 408,
#  'طقه تاک': 409,
#  'قوق قان': 410,
#  ' خویشتن': 411,
#  'درگیری ': 412,
#  'ری اردن': 413,
#  'ن درگیر': 414,
#  'د سعودی': 415,
#  'هد سعود': 416,
#  'امیان ت': 417,
#  ' شنبه و': 418,
#  ' السیسی': 419,
#  ' میایست': 420,
#  'تاح الس': 421,
#  'ر بیانی': 422,
#  'تگوی تل': 423,
#  ' تحولات': 424,
#  'مللی من': 425,
#  ' مصر تح': 426,
#  'ی رسمی ': 427,
#  'جهت توق': 428,
#  'کشور عر': 429,
#  'ها گفتگ': 430,
#  ' عربی م': 431,
#  'ت فلسطی': 432,
#  'رار غیر': 433,
#  'زوم تقو': 434,
#  'ری جلوگ': 435,
#  'ز سیاسی': 436,
#  'روع ایس': 437,
#  'رگیری م': 438,
#  'یکآمیز ': 439,
#  'ی تکرار': 440,
#  'ت محمد ': 441,
#  ' اهمیت ': 442,
#  'ی دستیا': 443,
#  'یها حقو': 444,
#  'نی نیرو': 445,
#  'عربستان': 446,
#  'نه درگی': 447,
#  'ن حقوق ': 448,
#  'لی بشرد': 449,
#  'ی بشردو': 450,
#  'اکید اس': 451,
#  'الفتاح ': 452,
#  'اکید رو': 453,
#  ' گروه ف': 454,
#  'ودی روز': 455,
#  ' اوضاع ': 456,
#  'سطین صد': 457,
#  'الگری ا': 458,
#  'طین اسا': 459,
#  'یلی دنب': 460,
#  'دستیابن': 461,
#  'یط بیسا': 462,
#  'یت خویش': 463,
#  'ی بدتر ': 464,
#  'تلزم تو': 465,
#  'عربی من': 466,
#  'صر تحول': 467,
#  'ی عربست': 468,
#  ' بیانی ': 469,
#  'تانه هد': 470,
#  'سطین اس': 471,
#  'باس تاک': 472,
#  'وار غزه': 473,
#  'اده خوا': 474,
#  'الله پا': 475,
#  'ق رویکر': 476,
#  'بال میک': 477,
#  'ل محروم': 478,
#  'ستان تح': 479,
#  'عباس تا': 480,
#  'وی ریاس': 481,
#  'ین حقوق': 482,
#  'اخلی فل': 483,
#  ' حساس ج': 484,
#  'ی جهتها': 485,
#  'ل جامع ': 486,
#  'ین صدور': 487,
#  'ل میکند': 488,
#  'یابی را': 489,
#  'ی رئیس ': 490,
#  'م حقوق ': 491,
#  'نالمللی': 492,
#  'دشاه ار': 493,
#  'لسطینیه': 494,
#  'سیاسی م': 495,
#  'فنی محم': 496,
#  'شردوستا': 497,
#  ' انفجار': 498,
#  'علام عر': 499,
#  'فجار او': 500,
#  ' اساس ر': 501,
#  'می عربس': 502,
#  'ت مسلما': 503,
#  'اقصی فل': 504,
#  'یزنیها ': 505,
#  'شرایط ب': 506,
#  'ض بارها': 507,
#  'تلاشها ': 508,
#  'بیسابقه': 509,
#  'و اهمیت': 510,
#  'ی ادامه': 511,
#  'ود عباس': 512,
#  'یدار بر': 513,
#  'امه اشغ': 514,
#  ' پایدار': 515,
#  'لسطینیا': 516,
#  'است محم': 517,
#  'تشکیلات': 518,
#  'تنی دست': 519,
#  'غیرنظام': 520,
#  'ه تاکید': 521,
#  ' سیاسی ': 522,
#  'گیری گس': 523,
#  'ابی راه': 524,
#  'ورت احت': 525,
#  'باس رئی': 526,
#  'یری بدت': 527,
#  'ع تاکید': 528,
#  'تاکید ا': 529,
#  'ند عدال': 530,
#  ' منطق ت': 531,
#  'مردم حق': 532,
#  'عهد عرب': 533,
#  'ساس راه': 534,
#  'تاکید ر': 535,
#  'ارجه عر': 536,
#  'اری رسم': 537,
#  'ستجمهور': 538,
#  'ری فصل ': 539,
#  'ق مشروع': 540,
#  'عملکرد ': 541,
#  'ار یاد ': 542,
#  'زاری فا': 543,
#  'بهمن وا': 544,
#  'دواریم ': 545,
#  'که گاز ': 546,
#  ' بهمن و': 547,
#  'ف میتوا': 548,
#  'ارف خان': 549,
#  'ذخیرهسا': 550,
#  'ف برق ج': 551,
#  'فیف تشو': 552,
#  'نگران ت': 553,
#  'یدواریم': 554,
#  'یان پیا': 555,
#  ' واحد ت': 556,
#  ' رعایت ': 557,
#  'یش مصرف': 558,
#  'یگزین ر': 559,
#  'یح ذخیر': 560,
#  'د تامین': 561,
#  'رین مصر': 562,
#  'یلی امس': 563,
#  'ن امیدو': 564,
#  'نعتی پر': 565,
#  'وانند ت': 566,
#  ' نگران ': 567,
#  ' مصرف ب': 568,
#  'ی موقع ': 569,
#  'سال گذش': 570,
#  'م معاون': 571,
#  'آور توج': 572,
#  'سریعتر ': 573,
#  'اره پیک': 574,
#  'ه معاون': 575,
#  'ین تجهی': 576,
#  'ار زنجا': 577,
#  'امه کاه': 578,
#  'یریت پا': 579,
#  'قرار یا': 580,
#  'گاز همک': 581,
#  'نداشته ': 582,
#  'امسال م': 583,
#  ' منابع ': 584,
#  'صحیح مص': 585,
#  'مختلف م': 586,
#  ' زنجان ': 587,
#  'تامین ت': 588,
#  'مکاری م': 589,
#  'ماه دی ': 590,
#  'رس سوخت': 591,
#  'ه اعمال': 592,
#  'ی توسعه': 593,
#  ' روز مد': 594,
#  'ر محمدی': 595,
#  'تلف مصر': 596,
#  'ند تاکی': 597,
#  'هار توج': 598,
#  'استفاده': 599,
#  'حیح شرک': 600,
#  'ر سال گ': 601,
#  'ه پایدا': 602,
#  'اسایی و': 603,
#  'ر اقتصا': 604,
#  'گران تع': 605,
#  'ستان زن': 606,
#  'دی توسع': 607,
#  'ولیدی ن': 608,
#  'گزین رو': 609,
#  'وار مدی': 610,
#  'ف خانگی': 611,
#  'محمدی ا': 612,
#  'شته خاط': 613,
#  'ار گاز ': 614,
#  'دیریت ش': 615,
#  'ه تشویق': 616,
#  'ین برنا': 617,
#  'ت گاز ط': 618,
#  'دارس اس': 619,
#  'ته خاطر': 620,
#  'رف تاکی': 621,
#  'وز مدیر': 622,
#  'ل تخفیف': 623,
#  'صارف خا': 624,
#  ' تامین ': 625,
#  'ر افت س': 626,
#  'ح شرکت ': 627,
#  'طیلی ام': 628,
#  'ز شرکت ': 629,
#  'داشته ب': 630,
#  'فاده سو': 631,
#  ' سرد اف': 632,
#  'دی تجار': 633,
#  'ین مدار': 634,
#  'واحد صن': 635,
#  'لان مشک': 636,
#  'ایدار ز': 637,
#  'خفیف مش': 638,
#  ' امروز ': 639,
#  'ی برنام': 640,
#  'استان ن': 641,
#  'ز استان': 642,
#  ' ماه دی': 643,
#  'صرف برق': 644,
#  'طبیعی ا': 645,
#  'زین برن': 646,
#  'رنامه م': 647,
#  'ن تعطیل': 648,
#  'ف سوخت ': 649,
#  ' زمستان': 650,
#  'یلی واح': 651,
#  'ی امور ': 652,
#  'ن گاز ط': 653,
#  'ه سوخت ': 654,
#  'ه منابع': 655,
#  'ذعان ام': 656,
#  'فرا فصو': 657,
#  'اطر افت': 658,
#  'گی نداش': 659,
#  ' اذعان ': 660,
#  'زایش مص': 661,
#  'مصارف خ': 662,
#  'ج مصرف ': 663,
#  'ن تجهیز': 664,
#  'ی رعایت': 665,
#  'احدها س': 666,
#  'ر زنجان': 667,
#  'رف برق ': 668,
#  'ر مشترک': 669,
#  'زیابی ت': 670,
#  'مصرف نگ': 671,
#  'اشند تا': 672,
#  'مه معاو': 673,
#  'صادی تو': 674,
#  'ه گاز ن': 675,
#  'امه معا': 676,
#  'بیعی مص': 677,
#  'شار گاز': 678,
#  'مدارس س': 679,
#  'ت پایدا': 680,
#  'اذعان ا': 681,
#  ' شناسای': 682,
#  'رنامه ک': 683,
#  'اقتصادی': 684,
#  'حمدی اس': 685,
#  'ان عملک': 686,
#  ' محمدی ': 687,
#  'مستان م': 688,
#  ' گاز کش': 689,
#  'یح مصرف': 690,
#  ' نارضای': 691,
#  'یف مشتر': 692,
#  'ر گاز ش': 693,
#  'حمدی مع': 694,
#  'هسازی م': 695,
#  'شترکان ': 696,
#  ' باشیم ': 697,
#  'ن حسین ': 698,
#  'رس زنجا': 699,
#  'عان امی': 700,
#  ' صحیح م': 701,
#  'تشویق م': 702,
#  'کشور رو': 703,
#  'ف گاز ت': 704,
#  'مجوار م': 705,
#  'ز همکار': 706,
#  'گاز طبی': 707,
#  'ف نگران': 708,
#  'مشکلی ت': 709,
#  'توسط شر': 710,
#  'ل فرا ف': 711,
#  'ور اقتص': 712,
#  'ین سوخت': 713,
#  'صنعتی پ': 714,
#  'عی استا': 715,
#  'از پاید': 716,
#  'امین تج': 717,
#  'ن برنام': 718,
#  'گذشته خ': 719,
#  'خفیف تش': 720,
#  'یرهسازی': 721,
#  'شند تاک': 722,
#  ' معاون ': 723,
#  'ته گاز ': 724,
#  'دار گاز': 725,
#  ' توسعه ': 726,
#  ' بازخور': 727,
#  'موثر سا': 728,
#  'اهنگی ا': 729,
#  'سوخت جا': 730,
#  'صحیح ذخ': 731,
#  'ن ماه د': 732,
#  'ید قرار': 733,
#  'مه کاهش': 734,
#  'شرکت گا': 735,
#  'مردم مس': 736,
#  'ترین مص': 737,
#  'گاز است': 738,
#  'صرف سوخ': 739,
#  'مین گاز': 740,
#  'شیم پای': 741,
#  'رات دول': 742,
#  'سوخت وا': 743,
#  'گاز پای': 744,
#  'ز تواند': 745,
#  'نجان ما': 746,
#  'ر روز م': 747,
#  'مسال مد': 748,
#  'ز مدیرا': 749,
#  'ین روز ': 750,
#  'مدی معا': 751,
#  'ار مدیر': 752,
#  'نجان اذ': 753,
#  'گاز توا': 754,
#  'رکان گا': 755,
#  'تان واح': 756,
#  'جوار مد': 757,
#  ' گاز طب': 758,
#  ' افزایش': 759,
#  'تخفیف ت': 760,
#  'تان همج': 761,
#  ' اوج مص': 762,
#  'م پایان': 763,
#  'یف تشوی': 764,
#  ' گاز زن': 765,
#  'زی موقع': 766,
#  'خانگی ا': 767,
#  'ط شرکت ': 768,
#  'شاره پی': 769,
#  'ابی توج': 770,
#  'امه تشو': 771,
#  'رس استا': 772,
#  'ایدار گ': 773,
#  'ور روز ': 774,
#  'دارس سو': 775,
#  'ه شناسا': 776,
#  'تان زنج': 777,
#  'مه تشوی': 778,
#  'جه شناس': 779,
#  'ان ماه ': 780,
#  'عطیلی ا': 781,
#  'ی بهمن ': 782,
#  'سط شرکت': 783,
#  ' ارائه ': 784,
#  'وقاف ام': 785,
#  'یلیون ت': 786,
#  ' خبر به': 787,
#  'یران کش': 788,
#  'ربع روس': 789,
#  'عروس در': 790,
#  'قف تنظی': 791,
#  'س شهرست': 792,
#  'واقع گل': 793,
#  'ت وقف گ': 794,
#  ' خانه ب': 795,
#  'اغی بزر': 796,
#  ' اورژان': 797,
#  'ودکان ب': 798,
#  'ه شهرست': 799,
#  ' عام ار': 800,
#  'ارس شهر': 801,
#  'مرتضی د': 802,
#  'انه بهد': 803,
#  'ئه خدما': 804,
#  'تابخانه': 805,
#  'راسیابک': 806,
#  'ی بهمسا': 807,
#  'زرگترین': 808,
#  'دسرپرست': 809,
#  ' هزینه ': 810,
#  'اغی سند': 811,
#  'یدی وقف': 812,
#  'د رویان': 813,
#  'رتضی دی': 814,
#  'یلیارد ': 815,
#  'وقف واق': 816,
#  'ت نگهدا': 817,
#  'قف عام ': 818,
#  ' حاج مح': 819,
#  'ان برآو': 820,
#  'عام ارز': 821,
#  'فتنی وا': 822,
#  'یون توم': 823,
#  'ه ساختم': 824,
#  ' استقرا': 825,
#  'روم اقد': 826,
#  'ریال خا': 827,
#  'ات ماند': 828,
#  'ستای اف': 829,
#  'ید وقف ': 830,
#  'ریت پزش': 831,
#  'آورد صا': 832,
#  'ود ساخت': 833,
#  'چراغی س': 834,
#  'ع گلندر': 835,
#  'یلمقانی': 836,
#  'مات بهد': 837,
#  ' تجلیل ': 838,
#  'گ اعیان': 839,
#  'پزشکی ب': 840,
#  ' بیسرپر': 841,
#  'فع حرم ': 842,
#  'راغی مج': 843,
#  'دیش حاج': 844,
#  ' علی جم': 845,
#  'اداره ا': 846,
#  'ه محروم': 847,
#  'هداشتی ': 848,
#  'ین واقف': 849,
#  'ف امور ': 850,
#  'اد صادق': 851,
#  'هرستان ': 852,
#  'نیت نگه': 853,
#  ' وقف شش': 854,
#  'ری تامی': 855,
#  'خت کتاب': 856,
#  'حداثی م': 857,
#  'بدسرپرس': 858,
#  'قف واقف': 859,
#  'انس همز': 860,
#  'کان بیس': 861,
#  'رسانید ': 862,
#  'یش حاج ': 863,
#  'فته وقف': 864,
#  ' قرار پ': 865,
#  'خیراندی': 866,
#  'استقرار': 867,
#  'قی وقف ': 868,
#  'رین واق': 869,
#  'ی بزرگت': 870,
#  'یال خان': 871,
#  'فارس وا': 872,
#  ' روستای': 873,
#  ' واقفان': 874,
#  ' فارس ش': 875,
#  'یارد ری': 876,
#  'تمان مس': 877,
#  'تفاده ا': 878,
#  'رنگار ف': 879,
#  'ستقرار ': 880,
#  'گترین و': 881,
#  'ان خیرا': 882,
#  ' میرود ': 883,
#  'ندگاری ': 884,
#  'همزمان ': 885,
#  'یش محمد': 886,
#  'ع ارزش ': 887,
#  'مربع رو': 888,
#  'ن واقفا': 889,
#  'قرار مر': 890,
#  ' رئیس س': 891,
#  ' اعیانی': 892,
#  'ر بهزاد': 893,
#  'قانی گف': 894,
#  'نور ارز': 895,
#  ' مجتمع ': 896,
#  'ن خیران': 897,
#  'ظیم ثبت': 898,
#  'رستان ن': 899,
#  ' سازمان': 900,
#  'سیابکلا': 901,
#  'ست وقف ': 902,
#  'نید وقف': 903,
#  ' محمد چ': 904,
#  'درسه خا': 905,
#  'زشکی به': 906,
#  'ع روستا': 907,
#  'ریه تجل': 908,
#  'اثی میل': 909,
#  'فان خیر': 910,
#  'رئیس سا': 911,
#  'ج محمد ': 912,
#  ' جمشیدی': 913,
#  ' رسانید': 914,
#  ' نور ثب': 915,
#  'برنگار ': 916,
#  'ده استق': 917,
#  'قف ششدا': 918,
#  'ماندگار': 919,
#  'گهداری ': 920,
#  'ارس واق': 921,
#  'حت مربع': 922,
#  'برآورد ': 923,
#  'قفان خی': 924,
#  ' حرم عل': 925,
#  'تان نور': 926,
#  'خانه مد': 927,
#  'ت ارائه': 928,
#  'د وقف ت': 929,
#  'ه مدرسه': 930,
#  'نگ اعیا': 931,
#  'نی واقف': 932,
#  'ونی نیت': 933,
#  'دامات م': 934,
#  'تنی واق': 935,
#  'نظیم ثب': 936,
#  ' مدرسه ': 937,
#  'رست بدس': 938,
#  'ثبت وقف': 939,
#  'ئیس ساز': 940,
#  'اج محمد': 941,
#  'اف امور': 942,
#  'رزش میل': 943,
#  'وس دریا': 944,
#  'اقف خیر': 945,
#  ' فوریت ': 946,
#  ' برآورد': 947,
#  'هنام شه': 948,
#  'م ثبت ر': 949,
#  'گفتنی و': 950,
#  'خانه به': 951,
#  'رگترین ': 952,
#  'زش میلی': 953,
#  ' خدمات ': 954,
#  'ه کودکا': 955,
#  'ر مرکز ': 956,
#  'حروم اق': 957,
#  'حمد چرا': 958,
#  'طبقه سا': 959,
#  'س واقف ': 960,
#  ' پیام م': 961,
#  ' وقف عا': 962,
#  'ف تنظیم': 963,
#  'ه وقف خ': 964,
#  'د چراغی': 965,
#  'بخوانید': 966,
#  'ورت محل': 967,
#  'چهارمحا': 968,
#  'ظهر خصو': 969,
#  'صوصا رو': 970,
#  'ر انتظا': 971,
#  'ری گاهی': 972,
#  'طق بخصو': 973,
#  ' اساس ب': 974,
#  'فوذ غبا': 975,
#  'ات شمال': 976,
#  'نقشه یا': 977,
#  'ل استان': 978,
#  ' باد پا': 979,
#  'ه افزای': 980,
#  'ان صاف ': 981,
#  'ری صاف ': 982,
#  'ناسی چه': 983,
#  'ر خصوصا': 984,
#  'بارش پر': 985,
#  'سمتی اب': 986,
#  ' صورت م': 987,
#  'ظار میر': 988,
#  'زش باد ': 989,
#  ' ظهر خص': 990,
#  'ی هواشن': 991,
#  'رمحال ب': 992,
#  'ارشنبه ': 993,
#  'تظار می': 994,
#  'نفوذ غب': 995,
#  'استان ب': 996,
#  'ر افزای': 997,
#  'اری صاف': 998,
#  ' انتظار': 999,
#  'بار رقی': 1000,
#  ...}

# %%
all_docs_uid=news_data_shingled.map(lambda x : x[0]).collect()
pairs=zip(all_docs_uid,indexes)
dic_docs =dict(pairs)
dic_docs
# Out:
# {'68feae4bbbedc2d54adbb2369': 1,
#  '2ad5a78866237762a3f742c51': 2,
#  '0097b5fec5d970750b90fa046': 3,
#  'f136d860f0dcbd6c98318e580': 4,
#  '7b85bc41da526e89274f20958': 5,
#  '1c79364ff8bf8a8fa096246a2': 6,
#  '5110de54dae55a6f8f7c3ed0a': 7,
#  '87b218ce3b0ac72d379358268': 8,
#  '837d37a4906f6fb14f43cc81f': 9,
#  '20df813955ff47aa322783bfb': 10,
#  '5497ccaecdd45e198003e79a2': 11,
#  '9337d28000d899408bb3b6722': 12,
#  '29cf32170839299276be24a6c': 13,
#  '78a1b366a87f861afa30ae8da': 14,
#  'c4eaa6025745b6a1e67c4b13d': 15,
#  '4f1a05b11ee33ff18bdb443ca': 16,
#  'a4d54448e8a57c0890acaf932': 17,
#  'e13ce3d66402beff728480ff8': 18,
#  '3fa6a7614e698338fd2cfa469': 19,
#  '299c48f3cdd7b211af6e87ab2': 20,
#  'ea093fec1ce5c4c0c5966f97f': 21,
#  '5a701cef1c33f70b07853c6d5': 22,
#  'a8db5d2a130f448c618d36506': 23,
#  '1abba23838648c3969429590e': 24,
#  '66a0d3eaadb9f636786cca5a8': 25,
#  'e6e46f0847e854336c7fca326': 26,
#  'dfb3b676e24a7158259fe97c1': 27,
#  '262e6d64699ba9ee3ad527045': 28,
#  '2b381ef8d9e2750e94a2b4123': 964,
#  'cc8645f6fe1b1828f90c624f6': 965,
#  'be44f65f028085b8f2ea50f14': 966,
#  'd3d698ff19d950f5663f61799': 967,
#  '5037fbb8ba49bb5f420b1d689': 968,
#  '40cc5f43ce17b60b414dc0ac3': 969,
#  '1d2bdce923328bc798e2ac619': 970,
#  '459e135c6f7c18ce7dcbadea0': 971,
#  '4f29968fc7760ae2887a5b943': 972,
#  '2a130b28674648521d7b60225': 973,
#  'e204091a90449f68374baceab': 974,
#  '8ee24db4d5271342757d873c5': 975,
#  '1d5613e87f758adb5297fed2c': 976,
#  'ae5d9ca138c1d419017bc9d79': 977,
#  'f049b75ed9f322456fda1de09': 978,
#  'b6cddad247f148a679be26be5': 979,
#  'da4165f3b87590fce1af1a483': 980,
#  '79c1dbdbc74cdc1a8a1626e6b': 981,
#  '57bc2d018423745f7e632f966': 982,
#  '5933deff13fda4683500b3cc9': 983,
#  '6218bd6fbc72681a37ee959b1': 984,
#  '794cfa6c524b2c46da80aa286': 985,
#  'fe24c311ab3cc4b0d5423618f': 986,
#  '57bc96552f5f6623af3338ce8': 987,
#  '8a474140674300f5597803775': 988,
#  'd8876a197670d23903890d276': 989,
#  'b6ba4244cbb68bc391811102b': 990,
#  'd1ee38cffe031e1bd440bffd6': 991,
#  '5ae6cb67ff87bf1991bc5f7f5': 992,
#  'e844130ee7c73379753db8ff9': 993,
#  '3302672f511bbada9efb14f08': 994,
#  '0e9e291bef0c3137ca7460591': 995,
#  'a712da09c32da2df651980a69': 996,
#  '0d6415cb19ae20164a1b8841e': 997,
#  '9bcef0b97f2c0759af3c36dc4': 998,
#  '6a9791525e58833838c181b7d': 999,
#  'cf40be0fbe6847a89ff610e3b': 1000,
#  ...}

# %%
# the family of hash functions, in this case, I use universal hash functions
import random
import math
random.seed(10)


# prime generator
p=2**31-1
class hashFamily:
    def __init__(self, i):
        self.hash_index=i
        self.a=random.randint(1,100)
        self.b=random.randint(1,1000)
    def get_hash_value(self, el_to_hash):
        return  (((self.a*el_to_hash)+self.b)%p)%len_unique

# %%
class minhashSigner:
    def __init__(self, sig_size):
        self.sig_size=sig_size
        self.hash_functions = [hashFamily(i) for i in range(0,sig_size)]

    def compute_set_signature(self, set_):
        set_sig = []
        for h_funct in self.hash_functions:
            min_hash = math.inf
            for el in set_:
                ell=dic_shingles[el]
                h = h_funct.get_hash_value(ell)
                if h < min_hash:
                    min_hash = h
            set_sig.append(min_hash)
        return set_sig

# %%
minhash = minhashSigner(m)
sig=news_data_shingled.map(lambda x:(x[0], minhash.compute_set_signature(list(x[1]))))

# %%
sig.take(1)
# Out:
# [('68feae4bbbedc2d54adbb2369',
#   [108,
#    550,
#    90,
#    501,
#    907,
#    706,
#    57,
#    569,
#    120,
#    1008,
#    466,
#    437,
#    636,
#    437,
#    345,
#    356,
#    238,
#    399,
#    457,
#    486,
#    980,
#    1024,
#    686,
#    95,
#    80,
#    169,
#    989,
#    589,
#    838,
#    353,
#    649,
#    505,
#    128,
#    683,
#    907,
#    226,
#    1023,
#    298,
#    38,
#    373,
#    752,
#    557,
#    165,
#    631,
#    983,
#    231,
#    1002,
#    892,
#    466,
#    849,
#    996,
#    489,
#    511,
#    730,
#    183,
#    615,
#    909,
#    290,
#    369,
#    699,
#    1050,
#    820,
#    515,
#    455,
#    488,
#    35,
#    800,
#    346,
#    290,
#    280,
#    473,
#    238,
#    993,
#    754,
#    785,
#    1001,
#    568,
#    679,
#    129,
#    524,
#    560,
#    192,
#    609,
#    433,
#    467,
#    782,
#    595,
#    159,
#    903,
#    898,
#    451,
#    136,
#    366,
#    168,
#    637,
#    913,
#    206,
#    942,
#    850,
#    1010,
#    410,
#    359,
#    560,
#    392,
#    617,
#    225,
#    339,
#    676,
#    709,
#    685,
#    666,
#    572,
#    831,
#    1001,
#    484,
#    768,
#    949,
#    60,
#    1013,
#    857,
#    851,
#    204,
#    575,
#    389,
#    488,
#    384,
#    106,
#    276,
#    268,
#    714,
#    949,
#    944,
#    866,
#    937,
#    807,
#    514,
#    848,
#    286,
#    647,
#    166,
#    883,
#    89,
#    462,
#    498,
#    942,
#    289,
#    800,
#    872,
#    856,
#    365,
#    402,
#    494,
#    297,
#    849,
#    515,
#    391,
#    577,
#    995,
#    449,
#    712,
#    402,
#    377,
#    990,
#    932,
#    664,
#    148,
#    642,
#    469,
#    508,
#    1010,
#    504,
#    671,
#    619,
#    951,
#    57,
#    412,
#    414,
#    769,
#    676,
#    338,
#    269,
#    204,
#    138,
#    882,
#    233,
#    836,
#    984,
#    251,
#    659,
#    994,
#    93,
#    258,
#    913,
#    270,
#    1023,
#    856,
#    1077,
#    934,
#    681,
#    682,
#    45,
#    448,
#    384,
#    731,
#    814,
#    142,
#    887,
#    214,
#    745,
#    593,
#    136,
#    501,
#    977,
#    107,
#    966,
#    781,
#    686,
#    798,
#    676,
#    386,
#    898,
#    1023,
#    598,
#    457,
#    125,
#    713,
#    63,
#    680,
#    277,
#    513,
#    620,
#    1033,
#    627,
#    177,
#    1020,
#    80,
#    256,
#    665,
#    443,
#    334,
#    412,
#    859,
#    135,
#    823,
#    529,
#    194,
#    881,
#    1084,
#    1024,
#    437,
#    183,
#    619,
#    522,
#    546,
#    995,
#    492,
#    420,
#    257,
#    447,
#    748,
#    781,
#    585,
#    954,
#    367,
#    702,
#    684,
#    578,
#    51,
#    248,
#    483,
#    324,
#    536,
#    863,
#    164,
#    1002,
#    649,
#    323,
#    118,
#    663,
#    616,
#    81,
#    883,
#    23,
#    942,
#    403,
#    768,
#    375,
#    683,
#    868,
#    42,
#    158,
#    1021,
#    279,
#    428,
#    638,
#    685,
#    949,
#    851,
#    133,
#    128,
#    863,
#    711,
#    885,
#    151,
#    484,
#    24,
#    530,
#    773,
#    664,
#    978,
#    572,
#    77,
#    476,
#    546,
#    403,
#    60,
#    695,
#    560,
#    822,
#    729])]

# %%
sss=sig.collect()
qq=dict(sss)

# %% [markdown]
# # STEP 3:  LSH

# %%
class LSH:
    def __init__(self, r,b, uid):
        self.uid=uid
        self.r=r
        self.b=b
        self.sig=qq[uid]
    def candidate_sig(self, uid):
        temp_Sig=qq[uid]
        flag=False
        for i in range(0,self.b):
            flag =flag or self.sig[r*i:r*i+r-1]==temp_Sig[r*i:r*i+r-1]
            if(flag):
                return True
        return(False)

# %%
# in this part I check is there any related news??
# do not run it again.
# for sample_uid  in all_docs_uid:
#     lsh=LSH(r,b,sample_uid)
#     ans=sig.filter(lambda x: lsh.candidate_sig(x[0])).map(lambda x: x[0]).collect()
#     # ans
#     final_uids=[]
#     final_uids.append(sample_uid)
#     ans.remove(sample_uid)
#     for u in ans:
#         set_sig_2 = set(qq[u])
#         set_sig_1 = set(qq[sample_uid])
#         jaccard_similarity_sig = len(set_sig_1.intersection(set_sig_2))/len(set_sig_1.union(set_sig_2))
#         if(jaccard_similarity_sig>s):
#             final_uids.append(u)
#     if(len(final_uids)>1):
#         print(final_uids)
# Out:
# ['68feae4bbbedc2d54adbb2369', 'a1fc8e369af3bb152173e01d8', '9179a70694ff478b8eb927e00', '8dc63b7fab7c218e25a3ab18e', 'c8c795b004c95a896b981c7d7', '53529513b997ca790c5fba898']
# ['0097b5fec5d970750b90fa046', 'aff311ec6247dc1da6696786f', '3b1d68aee6f11a2e81eb97b85', '73051ae16f5aca7afea5ab324', '31e2523b9b04829c2d8169f2f', '41585d069acc7677422c7aa34', 'a2c35c0be7d234b543bc2f3e0', '416d2daa79b8c4882f9d01efc', '8e09b7ae7ac94406b7333dea1', 'ed800395102f1a5ae8e0a61d3', '53ae8f879226a6b1e49257bf7', '3b7a9d48567489a42ce367491', '70476a21d663ec0ad5cb531a7', '48c852a5d47e22062e954a6ea', '49dde776179747c6a58fa0251', '74ad771ebdbb1f77bdcf45165', '1e1ac679c6ba0d3f44fa10417', 'dc605b69d6e8133971f3f8e81', '20f0ceb848db24b577cf50026', 'a3bb9bd94d160cac9b6bb5cdb', '0e3f165bba118c83af1f6d557', '7690321f836d92ae083a19898', 'f547ff972ffb13b6b0c5df797', '0184a2f6b9df84f2203d79f19', '64b45a051e5eb4a52a32f6ca6', '5900a8830f25a2ac0b1bd24ae', '1792e2a01cac0229db82a609f', '6171e56109d25250f66a20e8e', '81bb431e991d8caa9fbb4815a', '027bdf2cc9e29175725597a04', '0f0b7d5bd5c2793793917c502', 'd785d70e1755da5d90c811001', 'a483f1833e2a118ffc8a11c86', '52af9719b86a3e8a92acbb8ae', '43ad251a9779adca2d471d96f', 'b804a0561a31522cfa33996e5', '265393dfb07e14941dd416879', 'ec6cd9d05654f845f5ccc3dfd', '41e4ac6d74124b98b773c7746', 'ccd3d36de774d7b7c33bfa673', '082d3551f5788f6540cad51bd', '53a7e2a96f3fc8ffc9c50965d', '73b188a23f763e42be624dc33', '89a55ac3e6199914430ff05c8', '9a1be19105af48debce19bdc9', '903ce6488d2892184af911387', '64e37f9f91fa47202200fd0a1', '755aa1138b2f522a9fbfff854', '72f455ef6e34d95f4a076969a']
# ['87b218ce3b0ac72d379358268', '0889890588feea2a1e7cd5631']
a963342e240f6cc157c39ae', '5d1b23ed098df92a3d6ef1feb', 'e5650eb57e3bf9ec51b012b7e', '39ad72e01950e3dd73bed2ee4', '0a760400393b506a20a0c0d2b', 'f3e05bc7bc8f987b9331f5257', 'd91e4003ac11330a95b5d48c4', '0adb574a2a9e92625b6d1cbba', '317f8c5b3220256ae8d1d41e9', '16170760ac673544a5145a152', '6cf3db88a5ed649d944fd5bc3', '99d9291ca4ee04ebe5e68cdf7', '954a961b2302204ea6eab2243', 'ec2dfef6101c23be178d2db49', '4359d3053712c41be4280f658', '3039821e6ecf4f859d482a440', 'e150a2e16f57766dfe79761b8', 'c836aa0f31f85125356fea2d4', 'a68a0834b1a66630eef3a81c4', 'b1769862d9c4d659d440c7225', 'fb08b645466595fb9a6cd31d3', '292456676938255ce39656527', 'f83d46c67b1922ee1d7794099', '6a6c8c0201a32b49ebc0419ba', 'd41ca97d39d532e34a7353987', 'bee75f2fec4d3c5dc0e36878f ...
# ['e13ce3d66402beff728480ff8', '0c121ea5f3c89668a74620d8a']
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "C:\spark\spark-3.5.0-bin-hadoop3\python\lib\py4j-0.10.9.7-src.zip\py4j\java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "C:\spark\spark-3.5.0-bin-hadoop3\python\lib\py4j-0.10.9.7-src.zip\py4j\clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "C:\Users\Mehdi\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 3
#       1 for sample_uid  in all_docs_uid:
#       2     lsh=LSH(r,b,sample_uid)
# ----> 3     ans=sig.filter(lambda x: lsh.candidate_sig(x[0])).map(lambda x: x[0]).collect()
#       4     # ans
#       5     final_uids=[]
#
# File C:\spark\spark-3.5.0-bin-hadoop3\python\pyspark\rdd.py:1833, in RDD.collect(self)
#    1831 with SCCallSiteSync(self.context):
#    1832     assert self.ctx._jvm is not None
# -> 1833     sock_info = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#    1834 return list(_load_from_socket(sock_info, self._jrdd_deserializer))
#
# File C:\spark\spark-3.5.0-bin-hadoop3\python\lib\py4j-0.10.9.7-src.zip\py4j\java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File C:\spark\spark-3.5.0-bin-hadoop3\python\lib\py4j-0.10.9.7-src.zip\py4j\java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File C:\spark\spark-3.5.0-bin-hadoop3\python\lib\py4j-0.10.9.7-src.zip\py4j\clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File ~\anaconda3\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
sample_uid= 'e13ce3d66402beff728480ff8'
lsh=LSH(r,b,sample_uid)
ans=sig.filter(lambda x: lsh.candidate_sig(x[0])).map(lambda x: x[0]).collect()
final_uids=[]
final_uids.append(sample_uid)
ans.remove(sample_uid)
for u in ans:
    set_sig_2 = set(qq[u])
    set_sig_1 = set(qq[sample_uid])
    jaccard_similarity_sig = len(set_sig_1.intersection(set_sig_2))/len(set_sig_1.union(set_sig_2))
    if(jaccard_similarity_sig>s):
         final_uids.append(u)
if(len(final_uids)>1):
    print(final_uids)
# Out:
# ['e13ce3d66402beff728480ff8', '0c121ea5f3c89668a74620d8a']

# %%
print(ans)
# Out:
# ['0c121ea5f3c89668a74620d8a']

# %%
# above algorithm find ans list as a pair candidate
json_rdd.filter(lambda x : x['uid'] in final_uids).map(lambda x: (x['body'], x['keywords'])).take(10)
# Out:
# [('صادرات خودروهای تولید شده در ترکیه به کشورهای اتحادیه اروپا در نه ماه سال جاری (2023) نسبت به مدت مشابه سال قبل 22 درصد افزایش یافته است.\n\nبر اساس دادههای انجمن صادرکنندگان صنعت خودروی اولوداغ و مجمع صادرکنندگان ترکیه، این بخش محصولات خود را در بازه زمانی ژانویه تا سپتامبر به بیش از 190 کشور و همچنین مناطق مستقل و آزاد فروخته است.\n\nصادرات خودرو و صنایع مرتبط با آن در 9 امسال با افزایش 15 درصدی نسبت به دوره مشابه سال گذشته به 25 میلیارد و 619 میلیون و 838 هزار دلار رسید.\n\nهمچنین طبق این دادهها، سهم بخش خودرو از کل صادرات 15.7 درصد بوده است.\n\nاتحادیه اروپا با سهم 68.6 درصدی در صادرات خودروی ترکیه، در رده اول قرار دارد.\n\nهمچنین کشورهای آلمان و فرانسه به ترتیب در رده اول و دوم مقاصد صادراتی خودروهای تولید شده در ترکیه قرار دارند.',
#   ['انجمن صادرکنندگان صنعت خودروی اولوداغ',
#    'مجمع صادرکنندگان ترکیه',
#    'اتحادیه اروپا',
#    'صادرات خودرو']),
#  ('صادرات خودروهای تولید شده در ترکیه به کشورهای اتحادیه اروپا در نه ماه امسال 22 درصد افزایش یافت.\n\nصادرات خودروهای تولید شده در ترکیه به کشورهای اتحادیه اروپا در نه ماه سال جاری (2023) نسبت به مدت مشابه سال قبل 22 درصد افزایش یافته است.\n\nبر اساس دادههای انجمن صادرکنندگان صنعت خودروی اولوداغ و مجمع صادرکنندگان ترکیه، این بخش محصولات خود را در بازه زمانی ژانویه تا سپتامبر به بیش از 190 کشور و همچنین مناطق مستقل و آزاد فروخته است.\n\nصادرات خودرو و صنایع مرتبط با آن در 9 امسال با افزایش 15 درصدی نسبت به دوره مشابه سال گذشته به 25 میلیارد و 619 میلیون و 838 هزار دلار رسید.\n\nهمچنین طبق این دادهها، سهم بخش خودرو از کل صادرات 15.7 درصد بوده است.\n\nاتحادیه اروپا با سهم 68.6 درصدی در صادرات خودروی ترکیه، در رده اول قرار دارد.\n\nهمچنین کشورهای آلمان و فرانسه به ترتیب در رده اول و دوم مقاصد صادراتی خودروهای تولید شده در ترکیه قرار دارند.',
#   ['انجمن صادرکنندگان صنعت خودروی اولوداغ',
#    'اتحادیه اروپا',
#    'آلمان',
#    'اروپا'])]

# %%
# check sig similarity for sample and next element
ss1=final_uids[0]
ss2=final_uids[1]
set_sig_1 = set(qq[ss1])
set_sig_2 = set(qq[ss2])
jaccard_similarity_sig = len(set_sig_1.intersection(set_sig_2))/len(set_sig_1.union(set_sig_2))
print("jaccard similarity for signature is : "+ str(jaccard_similarity_sig))
# Out:
# jaccard similarity for signature is : 0.8357348703170029

# %%
# check thier shingle similarity for sample and next element

sad=news_data_shingled.filter(lambda x: x[0] in [ss1,ss2]).collect()
sad2=dict(sad)
jaccard_similarity_shingle_set = len(set(sad2[ss1].intersection(sad2[ss2])))/len(set(sad2[ss1].union(sad2[ss2])))
print("jaccard similarity for shingle set is : "+ str(jaccard_similarity_shingle_set))
# Out:
# jaccard similarity for shingle set is : 0.967391304347826
